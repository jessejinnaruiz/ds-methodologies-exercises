# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# %%
log_data  = pd.read_csv('access.log', sep='\s+',header=None)
log_data
# Out:
#                   0  1  2                      3       4  \
# 0      97.105.19.58  -  -  [16/Apr/2019:19:34:42  +0000]
# 1      97.105.19.58  -  -  [16/Apr/2019:19:34:42  +0000]
# 2      97.105.19.58  -  -  [16/Apr/2019:19:34:44  +0000]
# 3      97.105.19.58  -  -  [16/Apr/2019:19:34:46  +0000]
# 4      97.105.19.58  -  -  [16/Apr/2019:19:34:48  +0000]
# 5      97.105.19.58  -  -  [16/Apr/2019:19:34:48  +0000]
# 6      97.105.19.58  -  -  [16/Apr/2019:19:34:50  +0000]
# 7      97.105.19.58  -  -  [16/Apr/2019:19:34:52  +0000]
# 8      97.105.19.58  -  -  [16/Apr/2019:19:34:52  +0000]
# 9      97.105.19.58  -  -  [16/Apr/2019:19:34:53  +0000]
# 10     97.105.19.58  -  -  [16/Apr/2019:19:34:53  +0000]
# 11     97.105.19.58  -  -  [16/Apr/2019:19:34:53  +0000]
# 12     97.105.19.58  -  -  [16/Apr/2019:19:34:54  +0000]
# 13     97.105.19.58  -  -  [16/Apr/2019:19:34:54  +0000]
# 14     97.105.19.58  -  -  [16/Apr/2019:19:34:56  +0000]
# ...

# %%
log_data[3].dtype
# Out:
# dtype('O')

# %%
for col in log_data.columns:
    print(col, log_data[col].dtype)
# Out:
# 0 object
# 1 object
# 2 object
# 3 object
# 4 object
# 5 object
# 6 int64
# 7 int64
# 8 object
# 9 object

# %% [markdown]
# ### Concat columns 5-9 into a single column. This column represents the requests made

# %%
log_data['full_request']= log_data[5]+log_data[6].astype(str)+log_data[7].astype(str)+log_data[8]+log_data[9]
log_data.head()
# Out:
#               0  1  2                      3       4  \
# 0  97.105.19.58  -  -  [16/Apr/2019:19:34:42  +0000]
# 1  97.105.19.58  -  -  [16/Apr/2019:19:34:42  +0000]
# 2  97.105.19.58  -  -  [16/Apr/2019:19:34:44  +0000]
# 3  97.105.19.58  -  -  [16/Apr/2019:19:34:46  +0000]
# 4  97.105.19.58  -  -  [16/Apr/2019:19:34:48  +0000]
#
#                                     5    6       7  8                       9  \
# 0  GET /api/v1/sales?page=81 HTTP/1.1  200  512495  -  python-requests/2.21.0
# 1          GET /api/v1/items HTTP/1.1  200    3561  -  python-requests/2.21.0
# 2  GET /api/v1/sales?page=82 HTTP/1.1  200  510103  -  python-requests/2.21.0
# 3  GET /api/v1/sales?page=83 HTTP/1.1  200  510003  -  python-requests/2.21.0
# 4  GET /api/v1/sales?page=84 HTTP/1.1  200  511963  -  python-requests/2.21.0
#
#                                         full_request
# 0  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...
# 1  GET /api/v1/items HTTP/1.12003561-python-reque...
# ...

# %%
log_data = log_data.drop([1, 2], axis=1)

# %%
log_data = log_data.rename(columns={0:'IP_address', 3: 'date_time', 6: 'status_code', 7: 'size', 8:'unknown', 9:'user_agent'})

# %%
log_data['date_time'] = log_data['date_time'] + log_data[4]

# %%
log_data = log_data.drop([4], axis=1)

# %%
log_data['date_time'] = log_data['date_time'].str.replace('[','')

# %%
log_data['date_time'] = log_data['date_time'].str.replace(']','')

# %%
path_split = log_data[5].str.split('/',n=1, expand=True)
path_split.head()
# Out:
#       0                              1
# 0  GET   api/v1/sales?page=81 HTTP/1.1
# 1  GET           api/v1/items HTTP/1.1
# 2  GET   api/v1/sales?page=82 HTTP/1.1
# 3  GET   api/v1/sales?page=83 HTTP/1.1
# 4  GET   api/v1/sales?page=84 HTTP/1.1

# %%
log_data[5] = path_split[0]

# %%
log_data = log_data.rename(columns={5: 'request_method'})

# %%
log_data['path']=path_split[1]

# %%
path2 = log_data['path'].str.split(' ',n=1, expand=True)
path2
# Out:
#                            0         1
# 0       api/v1/sales?page=81  HTTP/1.1
# 1               api/v1/items  HTTP/1.1
# 2       api/v1/sales?page=82  HTTP/1.1
# 3       api/v1/sales?page=83  HTTP/1.1
# 4       api/v1/sales?page=84  HTTP/1.1
# 5              api/v1/stores  HTTP/1.1
# 6       api/v1/sales?page=85  HTTP/1.1
# 7       api/v1/sales?page=86  HTTP/1.1
# 8                             HTTP/1.1
# 9               api/v1/items  HTTP/1.1
# 10       api/v1/items?page=2  HTTP/1.1
# 11       api/v1/items?page=3  HTTP/1.1
# 12              api/v1/sales  HTTP/1.1
# 13      api/v1/sales?page=87  HTTP/1.1
# 14      api/v1/sales?page=88  HTTP/1.1
# 15      api/v1/sales?page=89  HTTP/1.1
# 16      api/v1/sales?page=90  HTTP/1.1
# 17      api/v1/sales?page=91  HTTP/1.1
# 18      api/v1/sales?page=92  HTTP/1.1
# 19      api/v1/sales?page=93  HTTP/1.1
# 20      api/v1/sales?page=94  HTTP/1.1
# 21      api/v1/sales?page=95  HTTP/1.1
# 22      api/v1/sales?page=96  HTTP/1.1
# ...

# %%
log_data['path']=path2[0]

# %%
log_data['protocol']=path2[1]

# %%
log_data.head()
# Out:
#      IP_address                  date_time request_method  status_code  \
# 0  97.105.19.58  16/Apr/2019:19:34:42+0000           GET           200
# 1  97.105.19.58  16/Apr/2019:19:34:42+0000           GET           200
# 2  97.105.19.58  16/Apr/2019:19:34:44+0000           GET           200
# 3  97.105.19.58  16/Apr/2019:19:34:46+0000           GET           200
# 4  97.105.19.58  16/Apr/2019:19:34:48+0000           GET           200
#
#      size unknown              user_agent  \
# 0  512495       -  python-requests/2.21.0
# 1    3561       -  python-requests/2.21.0
# 2  510103       -  python-requests/2.21.0
# 3  510003       -  python-requests/2.21.0
# 4  511963       -  python-requests/2.21.0
#
#                                         full_request                  path  \
# 0  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...  api/v1/sales?page=81
# 1  GET /api/v1/items HTTP/1.12003561-python-reque...          api/v1/items
# ...

# %%
log_data['date_time'] = log_data['date_time'].str.replace(':',' ',n=1)

# %%
log_data.head()
# Out:
#      IP_address                  date_time request_method  status_code  \
# 0  97.105.19.58  16/Apr/2019 19:34:42+0000           GET           200
# 1  97.105.19.58  16/Apr/2019 19:34:42+0000           GET           200
# 2  97.105.19.58  16/Apr/2019 19:34:44+0000           GET           200
# 3  97.105.19.58  16/Apr/2019 19:34:46+0000           GET           200
# 4  97.105.19.58  16/Apr/2019 19:34:48+0000           GET           200
#
#      size unknown              user_agent  \
# 0  512495       -  python-requests/2.21.0
# 1    3561       -  python-requests/2.21.0
# 2  510103       -  python-requests/2.21.0
# 3  510003       -  python-requests/2.21.0
# 4  511963       -  python-requests/2.21.0
#
#                                         full_request                  path  \
# 0  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...  api/v1/sales?page=81
# 1  GET /api/v1/items HTTP/1.12003561-python-reque...          api/v1/items
# ...

# %%
log_data['date_parsed'] = pd.to_datetime(log_data['date_time'], format = "%d/%b/%y %H%M%S", infer_datetime_format=True, utc=True)

# %%
log_data.head()
# Out:
#      IP_address                  date_time request_method  status_code  \
# 0  97.105.19.58  16/Apr/2019 19:34:42+0000           GET           200
# 1  97.105.19.58  16/Apr/2019 19:34:42+0000           GET           200
# 2  97.105.19.58  16/Apr/2019 19:34:44+0000           GET           200
# 3  97.105.19.58  16/Apr/2019 19:34:46+0000           GET           200
# 4  97.105.19.58  16/Apr/2019 19:34:48+0000           GET           200
#
#      size unknown              user_agent  \
# 0  512495       -  python-requests/2.21.0
# 1    3561       -  python-requests/2.21.0
# 2  510103       -  python-requests/2.21.0
# 3  510003       -  python-requests/2.21.0
# 4  511963       -  python-requests/2.21.0
#
#                                         full_request                  path  \
# 0  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...  api/v1/sales?page=81
# 1  GET /api/v1/items HTTP/1.12003561-python-reque...          api/v1/items
# ...

# %%
log_data = log_data.drop(['unknown', 'date_time'], axis=1)

# %%
log_data.head()
# Out:
#      IP_address request_method  status_code    size              user_agent  \
# 0  97.105.19.58           GET           200  512495  python-requests/2.21.0
# 1  97.105.19.58           GET           200    3561  python-requests/2.21.0
# 2  97.105.19.58           GET           200  510103  python-requests/2.21.0
# 3  97.105.19.58           GET           200  510003  python-requests/2.21.0
# 4  97.105.19.58           GET           200  511963  python-requests/2.21.0
#
#                                         full_request                  path  \
# 0  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...  api/v1/sales?page=81
# 1  GET /api/v1/items HTTP/1.12003561-python-reque...          api/v1/items
# 2  GET /api/v1/sales?page=82 HTTP/1.1200510103-py...  api/v1/sales?page=82
# 3  GET /api/v1/sales?page=83 HTTP/1.1200510003-py...  api/v1/sales?page=83
# 4  GET /api/v1/sales?page=84 HTTP/1.1200511963-py...  api/v1/sales?page=84
#
#    protocol               date_parsed
# ...

# %%
log_data['date_parsed'].dtype
# Out:
# datetime64[ns, UTC]

# %%
log_data.set_index('date_parsed', inplace=True)

# %%
log_data.head()
# Out:
#                              IP_address request_method  status_code    size  \
# date_parsed
# 2019-04-16 19:34:42+00:00  97.105.19.58           GET           200  512495
# 2019-04-16 19:34:42+00:00  97.105.19.58           GET           200    3561
# 2019-04-16 19:34:44+00:00  97.105.19.58           GET           200  510103
# 2019-04-16 19:34:46+00:00  97.105.19.58           GET           200  510003
# 2019-04-16 19:34:48+00:00  97.105.19.58           GET           200  511963
#
#                                        user_agent  \
# date_parsed
# 2019-04-16 19:34:42+00:00  python-requests/2.21.0
# 2019-04-16 19:34:42+00:00  python-requests/2.21.0
# 2019-04-16 19:34:44+00:00  python-requests/2.21.0
# 2019-04-16 19:34:46+00:00  python-requests/2.21.0
# 2019-04-16 19:34:48+00:00  python-requests/2.21.0
#
#                                                                 full_request  \
# date_parsed
# 2019-04-16 19:34:42+00:00  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...
# ...

# %%
log_data.tz_convert('America/Chicago').head()
# Out:
#                              IP_address request_method  status_code    size  \
# date_parsed
# 2019-04-16 14:34:42-05:00  97.105.19.58           GET           200  512495
# 2019-04-16 14:34:42-05:00  97.105.19.58           GET           200    3561
# 2019-04-16 14:34:44-05:00  97.105.19.58           GET           200  510103
# 2019-04-16 14:34:46-05:00  97.105.19.58           GET           200  510003
# 2019-04-16 14:34:48-05:00  97.105.19.58           GET           200  511963
#
#                                        user_agent  \
# date_parsed
# 2019-04-16 14:34:42-05:00  python-requests/2.21.0
# 2019-04-16 14:34:42-05:00  python-requests/2.21.0
# 2019-04-16 14:34:44-05:00  python-requests/2.21.0
# 2019-04-16 14:34:46-05:00  python-requests/2.21.0
# 2019-04-16 14:34:48-05:00  python-requests/2.21.0
#
#                                                                 full_request  \
# date_parsed
# 2019-04-16 14:34:42-05:00  GET /api/v1/sales?page=81 HTTP/1.1200512495-py...
# ...

# %%
log_data.to_csv('logs.csv')

# %%
log_data.user_agent.value_counts()
# Out:
# python-requests/2.21.0                                                                                                       12001
# python-requests/2.20.1                                                                                                        1911
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36       34
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0                                               8
# Slackbot-LinkExpanding 1.0 (+https://api.slack.com/robots)                                                                       7
# Slackbot 1.0 (+https://api.slack.com/robots)                                                                                     6
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36        4
# ...

# %%
def process_line(line: str):
    parts = line.split(' ')

    ip = parts[0]

    timestamp = parts[3] + parts[4]
    timestamp = timestamp.replace('[', '')
    timestamp = timestamp.replace(']', '')

    request_method = parts[5]
    request_method = request_method.replace('"', '')

    path = parts[6]
    protocol_version = parts[7]
    protocol_version = protocol_version.replace('"', '')
    status_code = parts[8]
    size = parts[9]
    unknown = parts[10]
    unknown = unknown.replace('"', '')
    user_agent = parts[11:]
    user_agent = ' '.join(user_agent)
    user_agent = user_agent.replace('"', '')

    return dict(ip=ip, timestamp=timestamp,
                method=request_method,
                path=path,
                protocol=protocol_version,
                code=status_code,
                size=size,
                unknown=unknown,
                user_agent=user_agent)
