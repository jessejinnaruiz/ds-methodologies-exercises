# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, expr
from pyspark.sql import functions as f
from pyspark.sql.functions import substring
from pyspark.sql.functions import sum, sumDistinct
from pyspark.sql import SparkSession, DataFrame, Column, Row, GroupedData, \
    DataFrameNaFunctions, DataFrameStatFunctions, functions, types, Window
from pyspark.sql import functions as f
from pyspark.sql.functions import mean, stddev, variance, skewness, kurtosis

from pyspark.sql.functions import count, countDistinct, approx_count_distinct

# %% [markdown]
# ## Some basic dataframe manipulation...

# %%
spark = pyspark.sql.SparkSession.builder.getOrCreate()

# %%
df = spark.read.csv('./example_data.txt')

# %%
df.show(4)
# Out:
# +----+---+
# | _c0|_c1|
# +----+---+
# |   n|  g|
# |15.0|  b|
# |23.0|  c|
# | 6.0|  c|
# +----+---+
# only showing top 4 rows

# %%
df = df.withColumnRenamed("_c0", "number").withColumnRenamed("_c1", "group")

# %%
df.show(5)
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# |   6.0|    c|
# |   NaN|    c|
# +------+-----+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- number: string (nullable = true)
#  |-- group: string (nullable = true)

# %%
df.withColumn("number", df.number.cast("integer")).show()
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |  null|    g|
# |    15|    b|
# |    23|    c|
# |     6|    c|
# |  null|    c|
# |    26|    b|
# |    12|    b|
# |     8|    a|
# |    18|    c|
# |    14|    a|
# |    20|    c|
# |    22|    a|
# |    21|    a|
# |     1|    c|
# |     0|    a|
# |    17|    b|
# |     2|    a|
# |     7|    a|
# |    16|    b|
# |    24|    b|
# +------+-----+
# only showing top 20 rows

# %%
df.show(3)
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# +------+-----+
# only showing top 3 rows

# %%
df.withColumn('n_is_even', df.number % 2 == 0).show()
# Out:
# +------+-----+---------+
# |number|group|n_is_even|
# +------+-----+---------+
# |     n|    g|     null|
# |  15.0|    b|    false|
# |  23.0|    c|    false|
# |   6.0|    c|     true|
# |   NaN|    c|    false|
# |  26.0|    b|     true|
# |  12.0|    b|     true|
# |   8.0|    a|     true|
# |  18.0|    c|     true|
# |  14.0|    a|     true|
# |  20.0|    c|     true|
# |  22.0|    a|     true|
# |  21.0|    a|    false|
# |   1.0|    c|    false|
# |   0.0|    a|     true|
# |  17.0|    b|    false|
# |   2.0|    a|     true|
# |   7.0|    a|    false|
# |  16.0|    b|     true|
# |  24.0|    b|     true|
# +------+-----+---------+
# only showing top 20 rows

# %%
df.show()
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# |   6.0|    c|
# |   NaN|    c|
# |  26.0|    b|
# |  12.0|    b|
# |   8.0|    a|
# |  18.0|    c|
# |  14.0|    a|
# |  20.0|    c|
# |  22.0|    a|
# |  21.0|    a|
# |   1.0|    c|
# |   0.0|    a|
# |  17.0|    b|
# |   2.0|    a|
# |   7.0|    a|
# |  16.0|    b|
# |  24.0|    b|
# +------+-----+
# only showing top 20 rows

# %%
df.selectExpr('*', 'number % 2 = 0 as number_is_even').show()
# Out:
# +------+-----+--------------+
# |number|group|number_is_even|
# +------+-----+--------------+
# |     n|    g|          null|
# |  15.0|    b|         false|
# |  23.0|    c|         false|
# |   6.0|    c|          true|
# |   NaN|    c|         false|
# |  26.0|    b|          true|
# |  12.0|    b|          true|
# |   8.0|    a|          true|
# |  18.0|    c|          true|
# |  14.0|    a|          true|
# |  20.0|    c|          true|
# |  22.0|    a|          true|
# |  21.0|    a|         false|
# |   1.0|    c|         false|
# |   0.0|    a|          true|
# |  17.0|    b|         false|
# |   2.0|    a|          true|
# |   7.0|    a|         false|
# |  16.0|    b|          true|
# |  24.0|    b|          true|
# +------+-----+--------------+
# only showing top 20 rows

# %%
df.drop('group').show()
# Out:
# +------+
# |number|
# +------+
# |     n|
# |  15.0|
# |  23.0|
# |   6.0|
# |   NaN|
# |  26.0|
# |  12.0|
# |   8.0|
# |  18.0|
# |  14.0|
# |  20.0|
# |  22.0|
# |  21.0|
# |   1.0|
# |   0.0|
# |  17.0|
# |   2.0|
# |   7.0|
# |  16.0|
# |  24.0|
# +------+
# only showing top 20 rows

# %%
df.limit(10).show()
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# |   6.0|    c|
# |   NaN|    c|
# |  26.0|    b|
# |  12.0|    b|
# |   8.0|    a|
# |  18.0|    c|
# |  14.0|    a|
# +------+-----+

# %% [markdown]
# # Using 311 Data...

# %%
spark = SparkSession.builder.master("local").appName("read").\
    enableHiveSupport().\
    getOrCreate()

# %%
df_case = spark.read.csv('./sa311/case.csv', sep=",", header=True, inferSchema=True)

# %%
df_case.show()
# Out:
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# |1014127335|     1/1/18 1:29|     1/2/18 8:13|1/17/18 8:30|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|
# |1014127336|     1/1/18 1:34|    1/1/18 13:29| 1/1/18 4:34|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|
# |1014127337|     1/1/18 6:28|    1/1/18 14:38|1/31/18 8:30|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|
# |1014127338|     1/1/18 6:57|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127339|     1/1/18 6:58|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127340|     1/1/18 6:58|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127341|     1/1/18 6:59|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127342|     1/1/18 7:00|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127343|     1/1/18 7:02|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127344|     1/1/18 7:02|    1/2/18 15:33|1/17/18 8:30|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|
# |1014127345|     1/1/18 7:03|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|
# |1014127346|     1/1/18 7:04|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|
# |1014127347|     1/1/18 7:04|    1/2/18 15:33|1/17/18 8:30|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127348|     1/1/18 7:05|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127349|     1/1/18 7:06|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127350|     1/1/18 7:06|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127351|     1/1/18 7:07|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+
# only showing top 20 rows

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: string (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: string (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_dept = spark.read.csv('./sa311/dept.csv', sep=",", header=True, inferSchema=True)

# %%
df_case = df_case.withColumn("case_opened_date", 
                   f.to_timestamp(f.col("case_opened_date"), 
                                  "M/d/yy H:mm")).\
        withColumn("case_closed_date", 
                   f.to_timestamp(f.col("case_closed_date"),
                                  "M/d/yy H:mm")).\
        withColumn("SLA_due_date", 
                   f.to_timestamp(f.col("SLA_due_date"),
                                  "M/d/yy H:mm"))

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.show(2)
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# only showing top 2 rows

# %% [markdown]
# ## How old is the latest (in terms of days past SLA) currently open issue? How long has the oldest (in terms of days since opened) currently opened issue been open?

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
row = df_case.select('SLA_days', 'num_days_late').sort(df_case.SLA_days, df_case.num_days_late, ascending=False).first()
row
# Out:
# Row(SLA_days=1420.0, num_days_late=-1417.0006019999998)

# %%
the_most_SLA = row['SLA_days']
the_most_SLA
# Out:
# 1420.0

# %%
the_most_numb_days_late = row['num_days_late']
the_most_numb_days_late
# Out:
# -1417.0006019999998

# %% [markdown]
# ## How many Stray Animal cases are there?

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.describe()
# Out:
# DataFrame[summary: string, case_id: string, case_late: string, num_days_late: string, case_closed: string, dept_division: string, service_request_type: string, SLA_days: string, case_status: string, source_id: string, request_address: string, council_district: string]

# %%
df_case.where(df_case.service_request_type == 'Stray Animal').count()
# Out:
# 26760

# %% [markdown]
# ### How many service requests that are assigned to the Field Operations department (dept_division) are not classified as "Officer Standby" request type (service_request_type)?

# %%
df_join = df_case.join(df_dept, "dept_division", "inner")

# %%
df_join.show()
# Out:
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %%
# pd_join  = df_join.toPandas().head()

# %%
# pd_join.head()

# %%
ans = df_join.where(df_join.dept_division == 'Field Operations').where(df_join.service_request_type != 'Officer Standby')

# %%
# ans.toPandas().head(5)

# %%
df_join.where(df_join.dept_division == 'Field Operations').where(df_join.service_request_type != 'Officer Standby').count()
# Out:
# 113902

# %% [markdown]
# ### Create a new DataFrame without any information related to dates or location.

# %%
df_join.dtypes
# Out:
# [('dept_division', 'string'),
#  ('case_id', 'int'),
#  ('case_opened_date', 'timestamp'),
#  ('case_closed_date', 'timestamp'),
#  ('SLA_due_date', 'timestamp'),
#  ('case_late', 'string'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'string'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'int'),
#  ('dept_name', 'string'),
#  ('standardized_dept_name', 'string'),
#  ('dept_subject_to_SLA', 'string')]

# %%
drop = ['request_address']
for element in df_join.dtypes:
    if element[1] == 'timestamp':
        drop.append(element[0])
drop
# Out:
# ['request_address', 'case_opened_date', 'case_closed_date', 'SLA_due_date']

# %%
# basically make a copy of the df_join, to make a new df to manipulate
df_nodates_location = df_join

# %%
for element in drop:
    df_nodates_location =  df_nodates_location.drop(element)
df_nodates_location.show()
df_nodates_location.printSchema()
# Out:
# +----------------+----------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+----------------+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|council_district|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+----------------+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|       NO| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|               5|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|       NO|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|       NO|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|       NO|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|               3|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|      YES|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|               7|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|       NO|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|               7|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|       NO|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|       NO|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|       NO|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|       NO|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|       NO|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|       NO|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|       NO|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|       NO|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|       NO|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|       NO|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|       NO|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|       NO|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|       NO|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|       NO|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+----------------+--------------------+----------------------+-------------------+
# only showing top 20 rows
#
# root
#  |-- dept_division: string (nullable = true)
#  |-- case_id: integer (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- council_district: integer (nullable = true)
#  |-- dept_name: string (nullable = true)
#  |-- standardized_dept_name: string (nullable = true)
#  |-- dept_subject_to_SLA: string (nullable = true)

# %% [markdown]
# ### Read dept.csv into a Spark DataFrame. Inspect the dept_name column. Replace the missing values with "other".

# %%
df_dept = spark.read.csv('./sa311/dept.csv', sep=",", header=True, inferSchema=True)
df_dept.show()
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|                null|  DSD/Code Enforcement|                YES|
# |   Dangerous Premise|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Dangerous Premise...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Director's Office...|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |          District 1|        City Council|          City Council|                 NO|
# |         District 10|        City Council|          City Council|                 NO|
# |          District 2|        City Council|          City Council|                 NO|
# |          District 3|        City Council|          City Council|                 NO|
# |          District 6|        City Council|          City Council|                 NO|
# |          District 7|        City Council|          City Council|                 NO|
# |          District 8|        City Council|          City Council|                 NO|
# |          District 9|        City Council|          City Council|                 NO|
# |Engineering Division|Development Services|  DSD/Code Enforcement|                YES|
# |    Facility License|        Metro Health|          Metro Health|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %%
df_dept = df_dept.fillna('other', ['dept_name'])

# %%
df_dept.show()
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|               other|  DSD/Code Enforcement|                YES|
# |   Dangerous Premise|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Dangerous Premise...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Director's Office...|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |          District 1|        City Council|          City Council|                 NO|
# |         District 10|        City Council|          City Council|                 NO|
# |          District 2|        City Council|          City Council|                 NO|
# |          District 3|        City Council|          City Council|                 NO|
# |          District 6|        City Council|          City Council|                 NO|
# |          District 7|        City Council|          City Council|                 NO|
# |          District 8|        City Council|          City Council|                 NO|
# |          District 9|        City Council|          City Council|                 NO|
# |Engineering Division|Development Services|  DSD/Code Enforcement|                YES|
# |    Facility License|        Metro Health|          Metro Health|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Convert the council_district column to a string column.

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.withColumn("council_district", df_case.council_district.cast("string")).printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: string (nullable = true)

# %%
df_join.printSchema()
# Out:
# root
#  |-- dept_division: string (nullable = true)
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)
#  |-- dept_name: string (nullable = true)
#  |-- standardized_dept_name: string (nullable = true)
#  |-- dept_subject_to_SLA: string (nullable = true)

# %%
df_join.withColumn("council_district", df_join.council_district.cast("string")).printSchema()
# Out:
# root
#  |-- dept_division: string (nullable = true)
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: string (nullable = true)
#  |-- dept_name: string (nullable = true)
#  |-- standardized_dept_name: string (nullable = true)
#  |-- dept_subject_to_SLA: string (nullable = true)

# %% [markdown]
# ### Extract the year from the case_closed_date column.

# %%
df_case.withColumn('year', substring('case_closed_date', 0, 4)).show()
# Out:
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# |   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# |1014127332|2018-01-01 00:42:00|            2018|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|     -23964.2102784|2018|
# |1014127333|2018-01-01 00:46:00|            2018|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|-48.302500007999996|2018|
# |1014127334|2018-01-01 00:48:00|            2018|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|      -72.536111112|2018|
# |1014127335|2018-01-01 01:29:00|            2018|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|      -360.27555552|2018|
# |1014127336|2018-01-01 01:34:00|            2018|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|  8.931944448000001|2018|
# |1014127337|2018-01-01 06:28:00|            2018|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7| -713.8555555199999|2018|
# |1014127338|2018-01-01 06:57:00|            2018|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.96166664|2018|
# |1014127339|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|
# |1014127340|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|
# |1014127341|2018-01-01 06:59:00|            2018|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|
# |1014127342|2018-01-01 07:00:00|            2018|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|
# |1014127343|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|
# |1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|
# |1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|
# |1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|
# |1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|
# |1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|
# |1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# only showing top 20 rows

# %%
df_case = df_case.withColumn('year', substring('case_closed_date', 0, 4))

# %%
df_case.show()
# Out:
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# |   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# |1014127332|2018-01-01 00:42:00|            2018|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|     -23964.2102784|2018|
# |1014127333|2018-01-01 00:46:00|            2018|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|-48.302500007999996|2018|
# |1014127334|2018-01-01 00:48:00|            2018|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|      -72.536111112|2018|
# |1014127335|2018-01-01 01:29:00|            2018|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|      -360.27555552|2018|
# |1014127336|2018-01-01 01:34:00|            2018|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|  8.931944448000001|2018|
# |1014127337|2018-01-01 06:28:00|            2018|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7| -713.8555555199999|2018|
# |1014127338|2018-01-01 06:57:00|            2018|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.96166664|2018|
# |1014127339|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|
# |1014127340|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|
# |1014127341|2018-01-01 06:59:00|            2018|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|
# |1014127342|2018-01-01 07:00:00|            2018|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|
# |1014127343|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|
# |1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|
# |1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|
# |1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|
# |1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|
# |1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|
# |1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# 24      Code Enforcement                      Front Or Side Yard Parking
# 25      Code Enforcement                      Front Or Side Yard Parking
# 26      Code Enforcement               Right Of Way/Sidewalk Obstruction
# 27      Code Enforcement                      Front Or Side Yard Parking
# 28      Code Enforcement                      Front Or Side Yard Parking
# 29      Code Enforcement               Right Of Way/Sidewalk Obstruction
# ...                  ...                                             ...
# 841674  Field Operations                                  Animal Neglect
# 841675  Field Operations                        Animal Cruelty(Critical)
# 841676  Field Operations                                  Animal Neglect
# 841677  Field Operations                 Aggressive Animal(Non-Critical)
# 841678  Field Operations                                    Stray Animal
# 841679  Field Operations                        Animal Cruelty(Critical)
# 841680  Field Operations                                  Animal Neglect
# 841681  Field Operations                                  Animal Neglect
# 841682  Field Operations                                  Animal Neglect
# 841683           Signals  Traffic Signal Ops and Maintenance - Emergency
# 841684  Field Operations                                  Animal Neglect
# 841685  Field Operations                         Trapped/Confined Animal
# 841686  Field Operations                                    Stray Animal
# 841687  Field Operations                        Animal Cruelty(Critical)
# 841688  Field Operations                        Injured Animal(Critical)
# 841689  Field Operations                                  Animal Neglect
# 841690  Field Operations                         Trapped/Confined Animal
# 841691  Code Enforcement                                Brush Violations
# 841692  Field Operations                        Animal Cruelty(Critical)
# 841693  Field Operations                                  Animal Neglect
# 841694           Signals  Traffic Signal Ops and Maintenance - Emergency
# 841695  Field Operations                                  Animal Neglect
# 841696           Signals  Traffic Signal Ops and Maintenance - Emergency
# 841697  Field Operations                        Animal Cruelty(Critical)
# 841698  Field Operations                         Trapped/Confined Animal
# 841699           Signals  Traffic Signal Ops and Maintenance - Emergency
# 841700  Field Operations                         Trapped/Confined Animal
# 841701           Signals  Traffic Signal Ops and Maintenance - Emergency
# 841702  Field Operations                                  Animal Neglect
# 841703  Field Operations                                  Animal Neglect
#
#           SLA_days case_status     source_id  \
# 0       999.000000      Closed      svcCRMLS
# 1         4.322222      Closed      svcCRMSS
# 2         4.320729      Closed      svcCRMSS
# 3        16.291887      Closed      svcCRMSS
# 4         0.125000      Closed      svcCRMSS
# 5        30.084468      Closed      svcCRMSS
# 6        16.064294      Closed      svcCRMSS
# 7        16.063796      Closed      svcCRMSS
# 8        16.063333      Closed      svcCRMSS
# 9        16.062859      Closed      svcCRMSS
# 10       16.062373      Closed      svcCRMSS
# 11       16.061042      Closed      svcCRMSS
# 12       16.060590      Closed      svcCRMSS
# 13       16.060116      Closed      svcCRMSS
# 14       16.059537      Closed      svcCRMSS
# 15       16.059074      Closed      svcCRMSS
# 16       16.058646      Closed      svcCRMSS
# 17       16.058194      Closed      svcCRMSS
# 18       16.057755      Closed      svcCRMSS
# 19       16.057338      Closed      svcCRMSS
# 20       16.056910      Closed      svcCRMSS
# 21       16.056435      Closed      svcCRMSS
# 22       16.055949      Closed      svcCRMSS
# 23       16.055498      Closed      svcCRMSS
# 24       16.055000      Closed      svcCRMSS
# 25       16.054560      Closed      svcCRMSS
# 26       16.054063      Closed      svcCRMSS
# 27       16.053657      Closed      svcCRMSS
# 28       16.053206      Closed      svcCRMSS
# 29       16.052801      Closed      svcCRMSS
# ...            ...         ...           ...
# 841674    5.000000      Closed        139345
# 841675    0.125000      Closed       dc12381
# 841676    5.000000      Closed        120752
# 841677    5.000000      Closed        139345
# 841678  999.000000      Closed        120752
# 841679    0.125000      Closed      svcCRMSS
# 841680    5.000000      Closed        120752
# 841681    5.000000      Closed        139345
# 841682    5.000000      Closed        120752
# 841683    2.534965      Closed  CRM_Listener
# 841684    5.000000      Closed        139345
# 841685    0.500000      Closed        120752
# 841686  999.000000      Closed        120752
# 841687    0.125000      Closed      svcCRMSS
# 841688    0.125000      Closed        120752
# 841689    5.000000      Closed        139345
# 841690    0.500000      Closed        120752
# 841691   65.478704      Closed      svcCRMSS
# 841692    0.125000      Closed      svcCRMSS
# 841693    5.000000      Closed        120752
# 841694    2.455787      Closed  CRM_Listener
# 841695    5.000000      Closed        120752
# 841696    2.437963      Closed  CRM_Listener
# 841697    0.125000      Closed      svcCRMSS
# 841698    0.500000      Closed        139345
# 841699    2.421319      Closed        120752
# 841700    0.500000      Closed        139345
# 841701    2.418275      Closed  CRM_Listener
# 841702    5.000000      Closed        139345
# 841703    5.000000      Closed        120752
#
#                                   request_address  council_district  year
# 0            2315  EL PASO ST, San Antonio, 78207                 5  2018
# 1             2215  GOLIAD RD, San Antonio, 78223                 3  2018
# 2           102  PALFREY ST W, San Antonio, 78223                 3  2018
# 3            114  LA GARDE ST, San Antonio, 78223                 3  2018
# 4           734  CLEARVIEW DR, San Antonio, 78228                 7  2018
# 5                        BANDERA RD and BRESNAHAN                 7  2018
# 6        10133  FIGARO CANYON, San Antonio, 78251                 4  2018
# 7        10133  FIGARO CANYON, San Antonio, 78251                 4  2018
# 8        10133  FIGARO CANYON, San Antonio, 78251                 4  2018
# 9        10133  FIGARO CANYON, San Antonio, 78251                 4  2018
# 10       10133  FIGARO CANYON, San Antonio, 78251                 4  2018
# 11       10133  FIGARO CANYON, San Antonio, 78251                 4  2018
# 12         10129  BOXING PASS, San Antonio, 78251                 4  2018
# 13         10129  BOXING PASS, San Antonio, 78251                 4  2018
# 14         10129  BOXING PASS, San Antonio, 78251                 4  2018
# 15          834  BARREL POINT, San Antonio, 78251                 4  2018
# 16          834  BARREL POINT, San Antonio, 78251                 4  2018
# 17          834  BARREL POINT, San Antonio, 78251                 4  2018
# 18          834  BARREL POINT, San Antonio, 78251                 4  2018
# 19          834  BARREL POINT, San Antonio, 78251                 4  2018
# 20          834  BARREL POINT, San Antonio, 78251                 4  2018
# 21          834  BARREL POINT, San Antonio, 78251                 4  2018
# 22          834  BARREL POINT, San Antonio, 78251                 4  2018
# 23          834  BARREL POINT, San Antonio, 78251                 4  2018
# 24          837  BARREL POINT, San Antonio, 78251                 4  2018
# 25          837  BARREL POINT, San Antonio, 78251                 4  2018
# 26          837  BARREL POINT, San Antonio, 78251                 4  2018
# 27          837  BARREL POINT, San Antonio, 78251                 4  2018
# 28          837  BARREL POINT, San Antonio, 78251                 4  2018
# 29          837  BARREL POINT, San Antonio, 78251                 4  2018
# ...                                           ...               ...   ...
2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|
# |1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|
# |1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|
# |1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|
# |1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|
# |1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|
# |1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# only showing top 20 rows

# %% [markdown]
# ### Convert the case_late column to a boolean column.

# %%
df_case.withColumn('case_late', df_case.case_late == "YES" ).show()
# Out:
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# |   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# |1014127332|2018-01-01 00:42:00|            2018|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|     -23964.2102784|2018|
# |1014127333|2018-01-01 00:46:00|            2018|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|-48.302500007999996|2018|
# |1014127334|2018-01-01 00:48:00|            2018|2018-01-05 08:30:00|    false|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|      -72.536111112|2018|
# |1014127335|2018-01-01 01:29:00|            2018|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|      -360.27555552|2018|
# |1014127336|2018-01-01 01:34:00|            2018|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|  8.931944448000001|2018|
# |1014127337|2018-01-01 06:28:00|            2018|2018-01-31 08:30:00|    false|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7| -713.8555555199999|2018|
# |1014127338|2018-01-01 06:57:00|            2018|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.96166664|2018|
# |1014127339|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|
# |1014127340|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|
# |1014127341|2018-01-01 06:59:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|
# |1014127342|2018-01-01 07:00:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|
# |1014127343|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|
# |1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|
# |1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|
# |1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|
# |1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|
# |1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|
# |1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|
# |1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|
# +----------+-------------------+----------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+
# only showing top 20 rows

# %%
df_case = df_case.withColumn('case_late', df_case.case_late == "YES" )

# %% [markdown]
# ### Convert the SLA_days columns to a double column.

# %%
df_case = df_case.withColumn("SLA_days", df_case.SLA_days.cast("double"))
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: boolean (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)
#  |-- num_hours_late: double (nullable = true)
#  |-- year: string (nullable = true)

# %% [markdown]
# ### Pull it all together (again)

# %%
df_join2 = df_case.join(df_dept, "dept_division", "inner")
df_join2.show()
# Out:
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|            2018|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|     -23964.2102784|2018|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|2018-01-01 00:46:00|            2018|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|-48.302500007999996|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|2018-01-01 00:48:00|            2018|2018-01-05 08:30:00|    false|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|      -72.536111112|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|            2018|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|      -360.27555552|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|2018-01-01 01:34:00|            2018|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|  8.931944448000001|2018|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|2018-01-01 06:28:00|            2018|2018-01-31 08:30:00|    false|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7| -713.8555555199999|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|            2018|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.96166664|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Create a DataFrame with all combinations of council_district and service_request_type (regardless of whether the combination is observed in the data).

# %%
df_allcombos = df_case.join(df_dept, df_case.dept_division == df_dept.dept_division, "full_outer")
df_allcombos.show(3)
# Out:
# +----------+-------------------+----------------+-------------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+--------------------+----------------+-------------------+----+-------------+--------------------+----------------------+-------------------+
# |   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|num_days_late|case_closed|dept_division|service_request_type|SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------+-------------------+----------------+-------------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+--------------------+----------------+-------------------+----+-------------+--------------------+----------------------+-------------------+
# |1014127378|2018-01-01 08:24:00|            2018|2018-01-03 08:24:00|    false|  -1.03287037|        YES|Miscellaneous|   Dead Animal - Cat|     2.0|     Closed|   139344|7059  TIMBERCREEK...|               6|       -24.78888888|2018|Miscellaneous|Solid Waste Manag...|           Solid Waste|                YES|
# |1014127411|2018-01-01 10:14:00|            2018|2018-01-03 10:14:00|    false| -1.160555556|        YES|Miscellaneous|   Dead Animal - Dog|     2.0|     Closed|   139344|6410  IH 35 N, Sa...|               2|      -27.853333344|2018|Miscellaneous|Solid Waste Manag...|           Solid Waste|                YES|
# |1014127439|2018-01-01 11:09:00|            2018|2018-01-03 11:09:00|    false| -1.154386574|        YES|Miscellaneous|   Dead Animal - Cat|     2.0|     Closed|   139344|5013  EVERS RD, S...|               7|-27.705277776000003|2018|Miscellaneous|Solid Waste Manag...|           Solid Waste|                YES|
# +----------+-------------------+----------------+-------------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+--------------------+----------------+-------------------+----+-------------+--------------------+----------------------+-------------------+
# only showing top 3 rows

# %% [markdown]
# ### Join the case data with the source and department data.

# %%
df_source = spark.read.csv('./sa311/source.csv', sep=",", header=True, inferSchema=True)

# %%
df_source.show(2)
# Out:
# +---------+----------------+
# |source_id| source_username|
# +---------+----------------+
# |   100137|Merlene Blodgett|
# |   103582|     Carmen Cura|
# +---------+----------------+
# only showing top 2 rows

# %%
df_join2.show()
# Out:
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|            2018|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|     -23964.2102784|2018|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|2018-01-01 00:46:00|            2018|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|-48.302500007999996|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|2018-01-01 00:48:00|            2018|2018-01-05 08:30:00|    false|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|      -72.536111112|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|            2018|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|      -360.27555552|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|2018-01-01 01:34:00|            2018|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|  8.931944448000001|2018|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|2018-01-01 06:28:00|            2018|2018-01-31 08:30:00|    false|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7| -713.8555555199999|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|            2018|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.96166664|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %%
df_all_files = df_join2.join(df_source, df_join2.source_id == df_source.source_id, 'left_outer')
df_all_files.show()
# Out:
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+---------+---------------+
# |   dept_division|   case_id|   case_opened_date|case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|     num_hours_late|year|           dept_name|standardized_dept_name|dept_subject_to_SLA|source_id|source_username|
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+---------+---------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|            2018|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|     -23964.2102784|2018|Animal Care Services|  Animal Care Services|                YES| svcCRMLS|       svcCRMLS|
# |     Storm Water|1014127333|2018-01-01 00:46:00|            2018|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|-48.302500007999996|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES| svcCRMSS|       svcCRMSS|
# |     Storm Water|1014127334|2018-01-01 00:48:00|            2018|2018-01-05 08:30:00|    false|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|      -72.536111112|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|            2018|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|      -360.27555552|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Field Operations|1014127336|2018-01-01 01:34:00|            2018|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|  8.931944448000001|2018|Animal Care Services|  Animal Care Services|                YES| svcCRMSS|       svcCRMSS|
# |         Signals|1014127337|2018-01-01 06:28:00|            2018|2018-01-31 08:30:00|    false|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7| -713.8555555199999|2018|Trans & Cap Impro...|  Trans & Cap Impro...|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|            2018|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.96166664|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|            2018|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95888888|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|            2018|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95583344|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|      -352.95277776|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|            2018|2018-01-17 08:30:00|    false|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.95000000000005|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|            2018|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|      -352.95277776|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|-352.94972232000003|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|            2018|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|-352.94138879999997|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|            2018|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.94416656|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|            2018|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|      -352.93833336|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|            2018|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|       -352.9355556|2018|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# +----------------+----------+-------------------+----------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+-------------------+----+--------------------+----------------------+-------------------+---------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### Are there any cases that do not have a request source?

# %%
df_join2.join(df_source, df_join2.source_id == df_source.source_id, "left_anti").show()
# Out:
# +-------------+-------+----------------+----------------+------------+---------+-------------+-----------+--------------------+--------+-----------+---------+---------------+----------------+--------------+----+---------+----------------------+-------------------+
# |dept_division|case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|num_days_late|case_closed|service_request_type|SLA_days|case_status|source_id|request_address|council_district|num_hours_late|year|dept_name|standardized_dept_name|dept_subject_to_SLA|
# +-------------+-------+----------------+----------------+------------+---------+-------------+-----------+--------------------+--------+-----------+---------+---------------+----------------+--------------+----+---------+----------------------+-------------------+
# +-------------+-------+----------------+----------------+------------+---------+-------------+-----------+--------------------+--------+-----------+---------+---------------+----------------+--------------+----+---------+----------------------+-------------------+

# %% [markdown]
# ## No

# %% [markdown]
# ### Who are the top 10 service request types in terms of number of requests?

# %%
df_all_files.toPandas().head()
# Out:
#       dept_division     case_id    case_opened_date case_closed_date  \
# 0  Field Operations  1014127332 2018-01-01 00:42:00             2018
# 1       Storm Water  1014127333 2018-01-01 00:46:00             2018
# 2       Storm Water  1014127334 2018-01-01 00:48:00             2018
# 3  Code Enforcement  1014127335 2018-01-01 01:29:00             2018
# 4  Field Operations  1014127336 2018-01-01 01:34:00             2018
#
#          SLA_due_date  case_late  num_days_late case_closed  \
# 0 2020-09-26 00:42:00      False    -998.508762         YES
# 1 2018-01-05 08:30:00      False      -2.012604         YES
# 2 2018-01-05 08:30:00      False      -3.022338         YES
# 3 2018-01-17 08:30:00      False     -15.011481         YES
# 4 2018-01-01 04:34:00       True       0.372164         YES
#
#          service_request_type    SLA_days       ...       source_id  \
# 0                Stray Animal  999.000000       ...        svcCRMLS
# 1      Removal Of Obstruction    4.322222       ...        svcCRMSS
# 2      Removal Of Obstruction    4.320729       ...        svcCRMSS
# 3  Front Or Side Yard Parking   16.291887       ...        svcCRMSS
# 4    Animal Cruelty(Critical)    0.125000       ...        svcCRMSS
#
#                          request_address council_district  num_hours_late  \
# 0   2315  EL PASO ST, San Antonio, 78207                5   -23964.210278
# 1    2215  GOLIAD RD, San Antonio, 78223                3      -48.302500
# 2  102  PALFREY ST W, San Antonio, 78223                3      -72.536111
# 3   114  LA GARDE ST, San Antonio, 78223                3     -360.275556
# 4  734  CLEARVIEW DR, San Antonio, 78228                7        8.931944
#
#    year                  dept_name    standardized_dept_name  \
# 0  2018       Animal Care Services      Animal Care Services
# 1  2018   Trans & Cap Improvements  Trans & Cap Improvements
# 2  2018   Trans & Cap Improvements  Trans & Cap Improvements
# 3  2018  Code Enforcement Services      DSD/Code Enforcement
# 4  2018       Animal Care Services      Animal Care Services
#
#   dept_subject_to_SLA source_id source_username
# 0                 YES  svcCRMLS        svcCRMLS
# 1                 YES  svcCRMSS        svcCRMSS
# 2                 YES  svcCRMSS        svcCRMSS
# 3                 YES  svcCRMSS        svcCRMSS
# 4                 YES  svcCRMSS        svcCRMSS
#
# [5 rows x 21 columns]

# %%
df_all_files.dtypes
# Out:
# [('dept_division', 'string'),
#  ('case_id', 'int'),
#  ('case_opened_date', 'timestamp'),
#  ('case_closed_date', 'string'),
#  ('SLA_due_date', 'timestamp'),
#  ('case_late', 'boolean'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'string'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'int'),
#  ('num_hours_late', 'double'),
#  ('year', 'string'),
#  ('dept_name', 'string'),
#  ('standardized_dept_name', 'string'),
#  ('dept_subject_to_SLA', 'string'),
#  ('source_id', 'string'),
#  ('source_username', 'string')]

# %%
top_service_requests = df_all_files.groupBy('service_request_type').agg(count('service_request_type').alias('count')).sort('count',ascending=False)
top_service_requests.show(10)
# Out:
# +--------------------+-----+
# |service_request_type|count|
# +--------------------+-----+
# |           No Pickup|89210|
# |Overgrown Yard/Trash|66403|
# |        Bandit Signs|32968|
# |        Damaged Cart|31163|
# |Front Or Side Yar...|28920|
# |        Stray Animal|27361|
# |Aggressive Animal...|25492|
# |Cart Exchange Req...|22608|
# |Junk Vehicle On P...|21649|
# |     Pot Hole Repair|20827|
# +--------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ### Who are the top 10 service request types in terms of average days late?

# %%
top_service_late = df_all_files.groupBy('service_request_type').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_service_late.show(10)
# Out:
# +--------------------+------------------+
# |service_request_type|     avg_days_late|
# +--------------------+------------------+
# |  Zoning: Junk Yards| 175.9563621042095|
# |Labeling for Used...|162.43032902285717|
# |Record Keeping of...|153.99724039428568|
# |Signage Requied f...|151.63868055333333|
# |Storage of Used M...|     142.112556415|
# |Zoning: Recycle Yard|135.92851612479797|
# |Donation Containe...|131.75610506358706|
# |License Requied U...|128.79828704142858|
# |Traffic Signal Gr...|101.79846062200002|
# |           Complaint| 72.87050230311695|
# +--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ### Does number of days late depend on department?

# %%
top_service_late_bydept = df_all_files.groupBy('service_request_type', 'dept_division').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_service_late_bydept.show(10)
# Out:
# +--------------------+--------------------+------------------+
# |service_request_type|       dept_division|     avg_days_late|
# +--------------------+--------------------+------------------+
# |  Zoning: Junk Yards|    Code Enforcement| 175.9563621042095|
# |Labeling for Used...|Code Enforcement ...|162.43032902285717|
# |Record Keeping of...|Code Enforcement ...|153.99724039428568|
# |Signage Requied f...|Code Enforcement ...|151.63868055333333|
# |Storage of Used M...|Code Enforcement ...|     142.112556415|
# |Zoning: Recycle Yard|Code Enforcement ...|135.92851612479797|
# |Donation Containe...|    Code Enforcement|131.75610506358706|
# |License Requied U...|Code Enforcement ...|128.79828704142858|
# |Traffic Signal Gr...|             Signals|101.79846062200002|
# |Used Mattress Ins...|Code Enforcement ...| 92.93570056835293|
# +--------------------+--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ### It seems like Code Enforcement Department has a lot of very late request types...

# %%
top_dept_late = df_all_files.groupBy('dept_division').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_dept_late.show(10)
# Out:
# +--------------------+------------------+
# |       dept_division|     avg_days_late|
# +--------------------+------------------+
# |Code Enforcement ...|135.92851612479797|
# |        Reservations|       66.03116319|
# |     311 Call Center|59.737091496300785|
# |Director's Office...|37.570646702950086|
# |Engineering Division| 13.43372455586971|
# |               Shops|  9.64126176872269|
# |           Tree Crew| 4.723282812065399|
# |         Solid Waste|3.5190239198762248|
# |              Trades| 3.231977141276932|
# |Clean and Green N...| 1.691468919487805|
# +--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ### How do number of days late depend on department division and request type?

# %%
top_dept_late_byservice = df_all_files.groupBy('dept_division', 'service_request_type').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_dept_late_byservice.show(10)
# Out:
# +--------------------+--------------------+------------------+
# |       dept_division|service_request_type|     avg_days_late|
# +--------------------+--------------------+------------------+
# |    Code Enforcement|  Zoning: Junk Yards| 175.9563621042095|
# |Code Enforcement ...|Labeling for Used...|162.43032902285717|
# |Code Enforcement ...|Record Keeping of...|153.99724039428568|
# |Code Enforcement ...|Signage Requied f...|151.63868055333333|
# |Code Enforcement ...|Storage of Used M...|     142.112556415|
# |Code Enforcement ...|Zoning: Recycle Yard|135.92851612479797|
# |    Code Enforcement|Donation Containe...|131.75610506358706|
# |Code Enforcement ...|License Requied U...|128.79828704142858|
# |             Signals|Traffic Signal Gr...|101.79846062200002|
# |Code Enforcement ...|Used Mattress Ins...| 92.93570056835293|
# +--------------------+--------------------+------------------+
# only showing top 10 rows
