# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, expr
from pyspark.sql import functions as f
from pyspark.sql.functions import substring
from pyspark.sql.functions import sum, sumDistinct
from pyspark.sql import SparkSession, DataFrame, Column, Row, GroupedData, \
    DataFrameNaFunctions, DataFrameStatFunctions, functions, types, Window
from pyspark.sql import functions as f
from pyspark.sql.functions import mean, stddev, variance, skewness, kurtosis

from pyspark.sql.functions import count, countDistinct, approx_count_distinct

# %% [markdown]
# ## Some basic dataframe manipulation...

# %%
spark = pyspark.sql.SparkSession.builder.getOrCreate()

# %%
df = spark.read.csv('./example_data.txt')

# %%
df.show(4)
# Out:
# +----+---+
# | _c0|_c1|
# +----+---+
# |   n|  g|
# |15.0|  b|
# |23.0|  c|
# | 6.0|  c|
# +----+---+
# only showing top 4 rows

# %%
df = df.withColumnRenamed("_c0", "number").withColumnRenamed("_c1", "group")

# %%
df.show(5)
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# |   6.0|    c|
# |   NaN|    c|
# +------+-----+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- number: string (nullable = true)
#  |-- group: string (nullable = true)

# %%
df.withColumn("number", df.number.cast("integer")).show()
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |  null|    g|
# |    15|    b|
# |    23|    c|
# |     6|    c|
# |  null|    c|
# |    26|    b|
# |    12|    b|
# |     8|    a|
# |    18|    c|
# |    14|    a|
# |    20|    c|
# |    22|    a|
# |    21|    a|
# |     1|    c|
# |     0|    a|
# |    17|    b|
# |     2|    a|
# |     7|    a|
# |    16|    b|
# |    24|    b|
# +------+-----+
# only showing top 20 rows

# %%
df.show(3)
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# +------+-----+
# only showing top 3 rows

# %%
df.withColumn('n_is_even', df.number % 2 == 0).show()
# Out:
# +------+-----+---------+
# |number|group|n_is_even|
# +------+-----+---------+
# |     n|    g|     null|
# |  15.0|    b|    false|
# |  23.0|    c|    false|
# |   6.0|    c|     true|
# |   NaN|    c|    false|
# |  26.0|    b|     true|
# |  12.0|    b|     true|
# |   8.0|    a|     true|
# |  18.0|    c|     true|
# |  14.0|    a|     true|
# |  20.0|    c|     true|
# |  22.0|    a|     true|
# |  21.0|    a|    false|
# |   1.0|    c|    false|
# |   0.0|    a|     true|
# |  17.0|    b|    false|
# |   2.0|    a|     true|
# |   7.0|    a|    false|
# |  16.0|    b|     true|
# |  24.0|    b|     true|
# +------+-----+---------+
# only showing top 20 rows

# %%
df.show()
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# |   6.0|    c|
# |   NaN|    c|
# |  26.0|    b|
# |  12.0|    b|
# |   8.0|    a|
# |  18.0|    c|
# |  14.0|    a|
# |  20.0|    c|
# |  22.0|    a|
# |  21.0|    a|
# |   1.0|    c|
# |   0.0|    a|
# |  17.0|    b|
# |   2.0|    a|
# |   7.0|    a|
# |  16.0|    b|
# |  24.0|    b|
# +------+-----+
# only showing top 20 rows

# %%
df.selectExpr('*', 'number % 2 = 0 as number_is_even').show()
# Out:
# +------+-----+--------------+
# |number|group|number_is_even|
# +------+-----+--------------+
# |     n|    g|          null|
# |  15.0|    b|         false|
# |  23.0|    c|         false|
# |   6.0|    c|          true|
# |   NaN|    c|         false|
# |  26.0|    b|          true|
# |  12.0|    b|          true|
# |   8.0|    a|          true|
# |  18.0|    c|          true|
# |  14.0|    a|          true|
# |  20.0|    c|          true|
# |  22.0|    a|          true|
# |  21.0|    a|         false|
# |   1.0|    c|         false|
# |   0.0|    a|          true|
# |  17.0|    b|         false|
# |   2.0|    a|          true|
# |   7.0|    a|         false|
# |  16.0|    b|          true|
# |  24.0|    b|          true|
# +------+-----+--------------+
# only showing top 20 rows

# %%
df.drop('group').show()
# Out:
# +------+
# |number|
# +------+
# |     n|
# |  15.0|
# |  23.0|
# |   6.0|
# |   NaN|
# |  26.0|
# |  12.0|
# |   8.0|
# |  18.0|
# |  14.0|
# |  20.0|
# |  22.0|
# |  21.0|
# |   1.0|
# |   0.0|
# |  17.0|
# |   2.0|
# |   7.0|
# |  16.0|
# |  24.0|
# +------+
# only showing top 20 rows

# %%
df.limit(10).show()
# Out:
# +------+-----+
# |number|group|
# +------+-----+
# |     n|    g|
# |  15.0|    b|
# |  23.0|    c|
# |   6.0|    c|
# |   NaN|    c|
# |  26.0|    b|
# |  12.0|    b|
# |   8.0|    a|
# |  18.0|    c|
# |  14.0|    a|
# +------+-----+

# %% [markdown]
# # Using 311 Data...

# %%
spark = SparkSession.builder.master("local").appName("read").\
    enableHiveSupport().\
    getOrCreate()

# %%
df_case = spark.read.csv('./sa311/case.csv', sep=",", header=True, inferSchema=True)

# %%
df_case.show()
# Out:
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+
# |   case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+
# |1014127332|     1/1/18 0:42|    1/1/18 12:29|9/26/20 0:42|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|     1/1/18 0:46|     1/3/18 8:11| 1/5/18 8:30|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# |1014127334|     1/1/18 0:48|     1/2/18 7:57| 1/5/18 8:30|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|
# |1014127335|     1/1/18 1:29|     1/2/18 8:13|1/17/18 8:30|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|
# |1014127336|     1/1/18 1:34|    1/1/18 13:29| 1/1/18 4:34|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|
# |1014127337|     1/1/18 6:28|    1/1/18 14:38|1/31/18 8:30|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|
# |1014127338|     1/1/18 6:57|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127339|     1/1/18 6:58|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127340|     1/1/18 6:58|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127341|     1/1/18 6:59|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127342|     1/1/18 7:00|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127343|     1/1/18 7:02|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|
# |1014127344|     1/1/18 7:02|    1/2/18 15:33|1/17/18 8:30|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|
# |1014127345|     1/1/18 7:03|    1/2/18 15:32|1/17/18 8:30|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|
# |1014127346|     1/1/18 7:04|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|
# |1014127347|     1/1/18 7:04|    1/2/18 15:33|1/17/18 8:30|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127348|     1/1/18 7:05|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127349|     1/1/18 7:06|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127350|     1/1/18 7:06|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# |1014127351|     1/1/18 7:07|    1/2/18 15:33|1/17/18 8:30|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|
# +----------+----------------+----------------+------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+
# only showing top 20 rows

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: string (nullable = true)
#  |-- case_closed_date: string (nullable = true)
#  |-- SLA_due_date: string (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_dept = spark.read.csv('./sa311/dept.csv', sep=",", header=True, inferSchema=True)

# %%
df_case = df_case.withColumn("case_opened_date", 
                   f.to_timestamp(f.col("case_opened_date"), 
                                  "M/d/yy H:mm")).\
        withColumn("case_closed_date", 
                   f.to_timestamp(f.col("case_closed_date"),
                                  "M/d/yy H:mm")).\
        withColumn("SLA_due_date", 
                   f.to_timestamp(f.col("SLA_due_date"),
                                  "M/d/yy H:mm"))

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.show(2)
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|   SLA_days|case_status|source_id|     request_address|council_district|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# |1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|      999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|
# |1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+-----------+-----------+---------+--------------------+----------------+
# only showing top 2 rows

# %% [markdown]
# ## How old is the latest (in terms of days past SLA) currently open issue? How long has the oldest (in terms of days since opened) currently opened issue been open?

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.sort(df_case.num_days_late, ascending=False).toPandas()
# Out:
#            case_id    case_opened_date    case_closed_date  \
# 0       1013288696 2017-01-26 15:36:00 2018-07-14 08:21:00
# 1       1013279603 2017-01-23 15:43:00 2018-07-06 14:14:00
# 2       1013279614 2017-01-23 15:45:00 2018-07-06 11:44:00
# 3       1013285103 2017-01-25 13:28:00 2018-07-03 11:44:00
# 4       1013276183 2017-01-22 09:42:00 2018-06-21 12:03:00
# 5       1013320288 2017-02-08 16:51:00 2018-07-12 17:54:00
# 6       1013249900 2017-01-11 14:54:00 2018-06-14 17:59:00
# 7       1013310957 2017-02-06 08:23:00 2018-07-07 16:35:00
# 8       1013338600 2017-02-16 08:04:00 2018-07-12 18:25:00
# 9       1013338595 2017-02-16 08:03:00 2018-07-12 18:24:00
# 10      1013398893 2017-03-09 15:36:00 2018-08-02 11:35:00
# 11      1013360238 2017-02-23 11:02:00 2018-07-17 17:27:00
# 12      1013346272 2017-02-19 08:41:00 2018-07-14 08:18:00
# 13      1013285457 2017-01-25 14:44:00 2018-06-18 13:32:00
# 14      1013285481 2017-01-25 14:48:00 2018-06-18 13:33:00
# 15      1013279276 2017-01-23 14:46:00 2018-06-14 17:24:00
# 16      1013285262 2017-01-25 13:59:00 2018-06-15 17:56:00
# 17      1013366204 2017-02-25 09:25:00 2018-07-17 17:43:00
# 18      1013388534 2017-03-06 13:02:00 2018-07-24 11:48:00
# 19      1013383588 2017-03-03 12:44:00 2018-07-21 10:26:00
# 20      1013319119 2017-02-08 12:37:00 2018-06-27 18:54:00
# 21      1013374765 2017-02-28 16:13:00 2018-07-17 17:55:00
# 22      1013394288 2017-03-08 11:09:00 2018-07-21 09:54:00
# 23      1013398052 2017-03-09 13:15:00 2018-07-21 11:24:00
# 24      1013413129 2017-03-15 12:01:00 2018-07-21 13:18:00
# 25      1013416634 2017-03-16 12:44:00 2018-07-21 14:40:00
# 26      1013356588 2017-02-22 10:31:00 2018-06-29 11:29:00
# 27      1013356610 2017-02-22 10:34:00 2018-06-29 11:29:00
# 28      1013416767 2017-03-16 13:09:00 2018-07-21 13:49:00
# 29      1013295025 2017-01-30 11:21:00 2018-07-24 17:34:00
# ...            ...                 ...                 ...
# 841674  1014351173 2018-03-22 12:06:00 2018-04-11 14:33:00
# 841675  1014365560 2018-03-27 10:53:00                 NaT
# 841676  1014393735 2018-04-04 16:31:00                 NaT
# 841677  1014397247 2018-04-05 14:59:00                 NaT
# 841678  1014433728 2018-04-17 15:20:00                 NaT
# 841679  1014437272 2018-04-18 14:37:00                 NaT
# 841680  1014443709 2018-04-20 11:29:00                 NaT
# 841681  1014493167 2018-05-08 10:54:00                 NaT
# 841682  1014493173 2018-05-08 10:55:00                 NaT
# 841683  1014498610 2018-05-09 16:40:00                 NaT
# 841684  1014499934 2018-05-10 10:08:00                 NaT
# 841685  1014507508 2018-05-13 10:34:00                 NaT
# 841686  1014558316 2018-05-30 11:35:00                 NaT
# 841687  1014558329 2018-05-30 11:37:00                 NaT
# 841688  1014565742 2018-06-01 11:52:00 2018-07-12 13:06:00
# 841689  1014573241 2018-06-04 16:00:00                 NaT
# 841690  1014573272 2018-06-04 16:05:00                 NaT
# 841691  1014574075 2018-06-04 20:50:00                 NaT
# 841692  1014598231 2018-06-12 16:53:00                 NaT
# 841693  1014606316 2018-06-14 22:26:00                 NaT
# 841694  1014759588 2018-08-08 10:33:00                 NaT
# 841695  1013632928 2017-06-09 13:47:00 2017-06-16 15:40:00
# 841696  1013762220 2017-08-01 10:43:00                 NaT
# 841697  1013810864 2017-08-21 15:22:00                 NaT
# 841698  1013817308 2017-08-23 15:47:00                 NaT
# 841699  1013855831 2017-09-06 15:17:00                 NaT
# 841700  1013867885 2017-09-11 16:24:00                 NaT
# 841701  1013936527 2017-10-09 12:11:00 2017-11-27 12:38:00
# 841702  1013939287 2017-10-10 10:57:00                 NaT
# 841703  1013940992 2017-10-10 16:34:00                 NaT
#
#               SLA_due_date  case_late  num_days_late case_closed  \
# 0      2017-02-09 15:36:00       True     519.698079         YES
# 1      2017-02-06 15:43:00       True     514.938194         YES
# 2      2017-02-06 15:45:00       True     514.832986         YES
# 3      2017-02-08 13:28:00       True     509.927685         YES
# 4      2017-01-31 08:30:00       True     506.148322         YES
# 5      2017-02-22 16:51:00       True     505.043831         YES
# 6      2017-01-26 14:54:00       True     504.128090         YES
# 7      2017-02-20 08:30:00       True     502.337442         YES
# 8      2017-03-02 08:30:00       True     497.413484         YES
# 9      2017-03-02 08:30:00       True     497.412662         YES
# 10     2017-03-23 15:36:00       True     496.832384         YES
# 11     2017-03-09 11:02:00       True     495.267488         YES
# 12     2017-03-06 08:30:00       True     494.991829         YES
# 13     2017-02-08 14:44:00       True     494.949838         YES
# 14     2017-02-08 14:48:00       True     494.948449         YES
# 15     2017-02-06 14:46:00       True     493.109479         YES
# 16     2017-02-08 13:59:00       True     492.164977         YES
# 17     2017-03-13 08:30:00       True     491.384282         YES
# 18     2017-03-20 13:02:00       True     490.948449         YES
# 19     2017-03-17 12:44:00       True     490.904410         YES
# 20     2017-02-22 12:37:00       True     490.262060         YES
# 21     2017-03-14 16:13:00       True     490.070752         YES
# 22     2017-03-22 11:09:00       True     485.947870         YES
# 23     2017-03-23 13:15:00       True     484.922859         YES
# 24     2017-03-29 12:01:00       True     479.053495         YES
# 25     2017-03-30 12:44:00       True     478.081030         YES
# 26     2017-03-08 10:31:00       True     478.040556         YES
# 27     2017-03-08 10:34:00       True     478.038079         YES
# 28     2017-03-30 13:09:00       True     478.028368         YES
# 29     2017-04-03 11:21:00       True     477.258935         YES
# ...                    ...        ...            ...         ...
# 841674                 NaT      False            NaN         YES
# 841675                 NaT      False            NaN          NO
# 841676                 NaT      False            NaN          NO
# 841677                 NaT      False            NaN          NO
# 841678                 NaT      False            NaN          NO
# 841679                 NaT      False            NaN          NO
# 841680                 NaT      False            NaN          NO
# 841681                 NaT      False            NaN          NO
# 841682                 NaT      False            NaN          NO
# 841683                 NaT      False            NaN          NO
# 841684                 NaT      False            NaN          NO
# 841685                 NaT      False            NaN          NO
# 841686                 NaT      False            NaN          NO
# 841687                 NaT      False            NaN          NO
# 841688                 NaT      False            NaN         YES
# 841689                 NaT      False            NaN          NO
# 841690                 NaT      False            NaN          NO
# 841691                 NaT      False            NaN          NO
# 841692                 NaT      False            NaN          NO
# 841693                 NaT      False            NaN          NO
# 841694                 NaT      False            NaN          NO
# 841695                 NaT      False            NaN         YES
# 841696                 NaT      False            NaN          NO
# 841697                 NaT      False            NaN          NO
# 841698                 NaT      False            NaN          NO
# 841699                 NaT      False            NaN          NO
# 841700                 NaT      False            NaN          NO
# 841701                 NaT      False            NaN         YES
# 841702                 NaT      False            NaN          NO
# 841703                 NaT      False            NaN          NO
#
#                       dept_division                    service_request_type  \
# 0                  Code Enforcement                            Bandit Signs
# 1                  Code Enforcement                       No Address Posted
# 2                  Code Enforcement                       No Address Posted
# 3                  Code Enforcement                            Bandit Signs
# 4                  Code Enforcement                        Permits Building
# 5                  Code Enforcement                            Bandit Signs
# 6                  Code Enforcement                            Bandit Signs
# 7                  Code Enforcement                       No Address Posted
# 8                  Code Enforcement                            Bandit Signs
# 9                  Code Enforcement                            Bandit Signs
# 10                 Code Enforcement                            Bandit Signs
# 11                 Code Enforcement                            Bandit Signs
# 12                 Code Enforcement                            Bandit Signs
# 13                 Code Enforcement                      Zoning: Junk Yards
# 14      Code Enforcement (Internal)                    Zoning: Recycle Yard
# 15                 Code Enforcement                             Curbstoning
# 16                 Code Enforcement                                 Vendors
# 17                 Code Enforcement                            Bandit Signs
# 18                 Code Enforcement                       No Address Posted
# 19                 Code Enforcement                       No Address Posted
# 20                 Code Enforcement                       No Address Posted
# 21                 Code Enforcement                            Bandit Signs
# 22                 Code Enforcement                       No Address Posted
# 23                 Code Enforcement                       No Address Posted
# 24                 Code Enforcement                       No Address Posted
# 25                 Code Enforcement                       No Address Posted
# 26                 Code Enforcement                      Zoning: Junk Yards
# 27      Code Enforcement (Internal)                    Zoning: Recycle Yard
# 28                 Code Enforcement                       No Address Posted
# 29                 Code Enforcement                        Permits Building
# ...                             ...                                     ...
# 841674                   District 1        Request for Research/Information
# 841675                   District 6        Request for Research/Information
# 841676                   District 3        Request for Research/Information
# 841677                   District 8        Request for Research/Information
# 841678                   District 8        Request for Research/Information
# 841679                   District 3        Request for Research/Information
# 841680                   District 9        Request for Research/Information
# 841681                   District 8        Request for Research/Information
# 841682                   District 8        Request for Research/Information
# 841683                   District 1        Request for Research/Information
# 841684                   District 6        Request for Research/Information
# 841685                   District 7        Request for Research/Information
# 841686                   District 8        Request for Research/Information
# 841687                   District 8        Request for Research/Information
# 841688                   District 1        Request for Research/Information
# 841689                   District 1        Request for Research/Information
# 841690                   District 1        Request for Research/Information
# 841691                   District 7        Request for Research/Information
# 841692                   District 1        Request for Research/Information
# 841693                   District 1        Request for Research/Information
# 841694                   District 2        Request for Research/Information
# 841695                   District 9        Request for Research/Information
# 841696                   District 6        Request for Research/Information
# 841697                   District 9        Request for Research/Information
# 841698                  District 10  CCO_Request for Research/Information_1
# 841699                   District 1        Request for Research/Information
# 841700                   District 1        Request for Research/Information
# 841701                   District 1        Request for Research/Information
# 841702                  District 10  CCO_Request for Research/Information_1
# 841703                   District 9        Request for Research/Information
#
#          SLA_days case_status     source_id  \
# 0       14.000000      Closed        138650
# 1       14.000000      Closed        139344
# 2       14.000000      Closed        139344
# 3       14.000000      Closed       ns16326
# 4        8.949398      Closed       mt13131
# 5       14.000000      Closed       dl05036
# 6       15.000000      Closed  CRM_Listener
# 7       14.004201      Closed       me05816
# 8       14.017905      Closed  CRM_Listener
# 9       14.018218      Closed  CRM_Listener
# 10      14.000000      Closed  CRM_Listener
# 11      14.000000      Closed       dl05036
# 12      14.992153      Closed        138810
# 13      14.000000      Closed  CRM_Listener
# 14      14.000000      Closed  CRM_Listener
# 15      14.000000      Closed       rs16746
# 16      14.000000      Closed       ns16326
# 17      15.961701      Closed  CRM_Listener
# 18      14.000000      Closed      svcCRMSS
# 19      14.000000      Closed        139344
# 20      14.000000      Closed       mt13131
# 21      14.000000      Closed       jw10936
# 22      14.000000      Closed       gp20685
# 23      14.000000      Closed       NO10960
# 24      14.000000      Closed       MW16328
# 25      14.000000      Closed       mp21218
# 26      14.000000      Closed  CRM_Listener
# 27      14.000000      Closed  CRM_Listener
# 28      14.000000      Closed      svcCRMSS
# 29      63.000000      Closed      svcCRMSS
# ...           ...         ...           ...
# 841674        NaN      Closed        140508
# 841675        NaN        Open        140508
# 841676        NaN        Open       np26458
# 841677        NaN        Open        140508
# 841678        NaN        Open        119868
# 841679        NaN        Open       np26458
# 841680        NaN        Open        142989
# 841681        NaN        Open        140508
# 841682        NaN        Open        140508
# 841683        NaN        Open        119868
# 841684        NaN        Open        140508
# 841685        NaN        Open        119868
# 841686        NaN        Open        120752
# 841687        NaN        Open        120752
# 841688        NaN      Closed       FC24472
# 841689        NaN        Open       FC24472
# 841690        NaN        Open       FC24472
# 841691        NaN        Open        142659
# 841692        NaN        Open       FC24472
# 841693        NaN        Open        142659
# 841694        NaN        Open       js12254
# 841695        NaN      Closed        138650
# 841696        NaN        Open        140436
# 841697        NaN        Open       bn26322
# 841698        NaN        Open       VM16785
# 841699        NaN        Open       FC24472
# 841700        NaN        Open       FC24472
# 841701        NaN      Closed        140508
# 841702        NaN        Open        140508
# 841703        NaN        Open       bn26322
#
#                                   request_address  council_district  year  \
# 0       10631  NACOGDOCHES RD, San Antonio, 78217                10  2018
# 1           6614  MONTEREY ST, San Antonio, 78227                 6  2018
# 2           6611  MONTEREY ST, San Antonio, 78227                 6  2018
# 3                    GRISSOM RD and TIMBERHILL DR                 7  2018
# 4             1122  PINE ST N, San Antonio, 78202                 2  2018
# 5              2605  SAUNDERS, San Antonio, 78207                 5  2018
# 6          1000  GUADALUPE ST, San Antonio, 78207                 5  2018
# 7                   511  K ST, San Antonio, 78220                 2  2018
# 8                     SALTILLO ST and ZARZAMORA S                 5  2018
# 9                     SALTILLO ST and ZARZAMORA S                 5  2018
# 10           3935  MEDICAL DR, San Antonio, 78229                 8  2018
# 11              1300  VERMONT, San Antonio, 78211                 5  2018
# 12               NACOGDOCHES RD and WURZBACH PKWY                10  2018
# 13        442  NEW LAREDO HWY, San Antonio, 78211                 5  2018
# 14        442  NEW LAREDO HWY, San Antonio, 78211                 5  2018
# 15                       SAUNDERS and ZARZAMORA S                 5  2018
# 16                        FM 78 and WOODLAKE PKWY                 2  2018
# 17                             BORIS and DIVISION                 5  2018
# 18              815  PRADO ST, San Antonio, 78225                 5  2018
# 19             400  KEMPER ST, San Antonio, 78207                 5  2018
# 20              10302  LORENE, San Antonio, 78216                 1  2018
# 21              431  HAZEL ST, San Antonio, 78207                 5  2018
# 22            115  WESTWAY DR, San Antonio, 78225                 5  2018
# 23        747  GEN MCMULLEN S, San Antonio, 78237                 5  2018
# 24         425  SAN HORACIO N, San Antonio, 78228                 5  2018
# 25              129  SOUTHWAY, San Antonio, 78225                 5  2018
# 26        4805  ROOSEVELT AVE, San Antonio, 78214                 3  2018
# 27        4805  ROOSEVELT AVE, San Antonio, 78214                 3  2018
# 28          400  MENEFEE BLVD, San Antonio, 78207                 5  2018
# 29               6210  410 NW, San Antonio, 78238                 7  2018
# ...                                           ...               ...   ...
# 841674                    BROADWAY and GREENBRIER                 1  2018
# 841675     5103  COLTON CREEK, San Antonio, 78251                 6  None
# 841676                     OFFER and SOUTHCROSS E                 3  None
# 841677               HUEBNER RD and VANCE JACKSON                 8  None
# 841678    13727  HUNTERS MOSS, San Antonio, 78230                 8  None
# 841679       500  HANSFORD ST, San Antonio, 78210                 3  None
# 841680               BABCOCK RD and BEVERLY MAE E                 8  None
# 841681                  BAYWATER DR and LYCEUM DR                 7  None
# 841682                  BAYWATER DR and LYCEUM DR                 7  None
# 841683      924  AGARITA AV W, San Antonio, 78201                 1  None
# 841684           MILITARY DR W and RAPLA CROSSING                 6  None
# 841685                 ELMENDORF N and WOODLAWN W                 7  None
# 841686      7600  AUTUMN PARK, San Antonio, 78249                 8  None
# 841687      7600  AUTUMN PARK, San Antonio, 78249                 8  None
# 841688              FREILING DR and VANCE JACKSON                 1  2018
# 841689              FREILING DR and VANCE JACKSON                 1  None
# 841690              FREILING DR and VANCE JACKSON                 1  None
# 841691   2602  HUISACHE AVE W, San Antonio, 78228                 7  None
# 841692                      BARBET and PILGRIM DR                 1  None
# 841693      115  SCHREINER PL, San Antonio, 78212                 1  None
# 841694     923  VIRGINIA BLVD, San Antonio, 78203                 2  None
# 841695    1100  SAN PEDRO AVE, San Antonio, 78212                 1  2017
# 841696                CULEBRA RD and VILLAGE PKWY                 6  None
# 841697    1323  BLUE CREST LN, San Antonio, 78232                 9  None
# 841698                 AUTRY POND and BULVERDE RD                10  None
# 841699                   MONTVIEW and ORLAND PARK                 1  None
# 841700          5807  IH 10 W, San Antonio, 78201                 1  None
# 841701       1013  SACRAMENTO, San Antonio, 78201                 1  2017
# 841702   2930  MACARTHUR VIEW, San Antonio, 78217                10  None
# 841703    110  PASO DEL NORTE, San Antonio, 78232                 9  None
#
#         num_hours_late
# 0         12472.753889
# 1         12358.516666
# 2         12355.991666
# 3         12238.264445
# 4         12147.559723
# 5         12121.051944
# 6         12099.074167
# 7         12056.098610
# 8         11937.923611
# 9         11937.903888
# 10        11923.977223
# 11        11886.419722
# 12        11879.803889
# 13        11878.796112
# 14        11878.762778
# 15        11834.627501
# 16        11811.959446
# 17        11793.222778
# 18        11782.762778
# 19        11781.705833
# 20        11766.289445
# 21        11761.698055
# 22        11662.748890
# 23        11638.148611
# 24        11497.283890
# 25        11473.944722
# 26        11472.973334
# 27        11472.913889
# 28        11472.680834
# 29        11454.214445
# ...                ...
# 841674             NaN
# 841675             NaN
# 841676             NaN
# 841677             NaN
# 841678             NaN
# 841679             NaN
# 841680             NaN
# 841681             NaN
# 841682             NaN
# 841683             NaN
# 841684             NaN
# 841685             NaN
# 841686             NaN
# 841687             NaN
# 841688             NaN
# 841689             NaN
# 841690             NaN
# 841691             NaN
# 841692             NaN
# 841693             NaN
# 841694             NaN
# 841695             NaN
# 841696             NaN
# 841697             NaN
# 841698             NaN
# 841699             NaN
# 841700             NaN
# 841701             NaN
# 841702             NaN
# 841703             NaN
#
# [841704 rows x 16 columns]

# %%
row = df_case.select('SLA_days', 'num_days_late').sort(df_case.num_days_late, ascending=False).first()
row
# Out:
# Row(SLA_days=14.0, num_days_late=519.6980787)

# %%
the_most_SLA = row['SLA_days']
the_most_SLA
# Out:
# 14.0

# %%
the_most_numb_days_late = row['num_days_late']
the_most_numb_days_late
# Out:
# 519.6980787

# %% [markdown]
# ## How many Stray Animal cases are there?

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.describe()
# Out:
# DataFrame[summary: string, case_id: string, case_late: string, num_days_late: string, case_closed: string, dept_division: string, service_request_type: string, SLA_days: string, case_status: string, source_id: string, request_address: string, council_district: string]

# %%
df_case.where(df_case.service_request_type == 'Stray Animal').count()
# Out:
# 26760

# %% [markdown]
# ### How many service requests that are assigned to the Field Operations department (dept_division) are not classified as "Officer Standby" request type (service_request_type)?

# %%
df_join = df_case.join(df_dept, "dept_division", "inner")

# %%
df_join.show()
# Out:
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %%
# pd_join  = df_join.toPandas().head()

# %%
# pd_join.head()

# %%
ans = df_join.where(df_join.dept_division == 'Field Operations').where(df_join.service_request_type != 'Officer Standby')

# %%
# ans.toPandas().head(5)

# %%
df_join.where(df_join.dept_division == 'Field Operations').where(df_join.service_request_type != 'Officer Standby').count()
# Out:
# 113902

# %% [markdown]
# ### Create a new DataFrame without any information related to dates or location.

# %%
df_join.dtypes
# Out:
# [('dept_division', 'string'),
#  ('case_id', 'int'),
#  ('case_opened_date', 'timestamp'),
#  ('case_closed_date', 'timestamp'),
#  ('SLA_due_date', 'timestamp'),
#  ('case_late', 'string'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'string'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'int'),
#  ('dept_name', 'string'),
#  ('standardized_dept_name', 'string'),
#  ('dept_subject_to_SLA', 'string')]

# %%
drop = ['request_address']
for element in df_join.dtypes:
    if element[1] == 'timestamp':
        drop.append(element[0])
drop
# Out:
# ['request_address', 'case_opened_date', 'case_closed_date', 'SLA_due_date']

# %%
# basically make a copy of the df_join, to make a new df to manipulate
df_nodates_location = df_join

# %%
for element in drop:
    df_nodates_location =  df_nodates_location.drop(element)
df_nodates_location.show()
df_nodates_location.printSchema()
# Out:
# +----------------+----------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+----------------+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|council_district|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+----------------+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|       NO| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|               5|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|       NO|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|       NO|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|               3|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|       NO|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|               3|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|      YES|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|               7|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|       NO|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|               7|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|       NO|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|       NO|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|       NO|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|       NO|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|       NO|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|       NO|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|       NO|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|       NO|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|       NO|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|       NO|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|       NO|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|       NO|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|       NO|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|       NO|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|               4|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+----------------+--------------------+----------------------+-------------------+
# only showing top 20 rows
#
# root
#  |-- dept_division: string (nullable = true)
#  |-- case_id: integer (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- council_district: integer (nullable = true)
#  |-- dept_name: string (nullable = true)
#  |-- standardized_dept_name: string (nullable = true)
#  |-- dept_subject_to_SLA: string (nullable = true)

# %% [markdown]
# ### Read dept.csv into a Spark DataFrame. Inspect the dept_name column. Replace the missing values with "other".

# %%
df_dept = spark.read.csv('./sa311/dept.csv', sep=",", header=True, inferSchema=True)
df_dept.show()
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|                null|  DSD/Code Enforcement|                YES|
# |   Dangerous Premise|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Dangerous Premise...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Director's Office...|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |          District 1|        City Council|          City Council|                 NO|
# |         District 10|        City Council|          City Council|                 NO|
# |          District 2|        City Council|          City Council|                 NO|
# |          District 3|        City Council|          City Council|                 NO|
# |          District 6|        City Council|          City Council|                 NO|
# |          District 7|        City Council|          City Council|                 NO|
# |          District 8|        City Council|          City Council|                 NO|
# |          District 9|        City Council|          City Council|                 NO|
# |Engineering Division|Development Services|  DSD/Code Enforcement|                YES|
# |    Facility License|        Metro Health|          Metro Health|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %%
df_dept = df_dept.fillna('other', ['dept_name'])

# %%
df_dept.show()
# Out:
# +--------------------+--------------------+----------------------+-------------------+
# |       dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +--------------------+--------------------+----------------------+-------------------+
# |     311 Call Center|    Customer Service|      Customer Service|                YES|
# |               Brush|Solid Waste Manag...|           Solid Waste|                YES|
# |     Clean and Green|Parks and Recreation|    Parks & Recreation|                YES|
# |Clean and Green N...|Parks and Recreation|    Parks & Recreation|                YES|
# |    Code Enforcement|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement ...|               other|  DSD/Code Enforcement|                YES|
# |   Dangerous Premise|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Dangerous Premise...|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Director's Office...|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |          District 1|        City Council|          City Council|                 NO|
# |         District 10|        City Council|          City Council|                 NO|
# |          District 2|        City Council|          City Council|                 NO|
# |          District 3|        City Council|          City Council|                 NO|
# |          District 6|        City Council|          City Council|                 NO|
# |          District 7|        City Council|          City Council|                 NO|
# |          District 8|        City Council|          City Council|                 NO|
# |          District 9|        City Council|          City Council|                 NO|
# |Engineering Division|Development Services|  DSD/Code Enforcement|                YES|
# |    Facility License|        Metro Health|          Metro Health|                YES|
# +--------------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Convert the council_district column to a string column.

# %%
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)

# %%
df_case.withColumn("council_district", df_case.council_district.cast("string")).printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: string (nullable = true)

# %%
df_join.printSchema()
# Out:
# root
#  |-- dept_division: string (nullable = true)
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)
#  |-- dept_name: string (nullable = true)
#  |-- standardized_dept_name: string (nullable = true)
#  |-- dept_subject_to_SLA: string (nullable = true)

# %%
df_join.withColumn("council_district", df_join.council_district.cast("string")).printSchema()
# Out:
# root
#  |-- dept_division: string (nullable = true)
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: string (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: string (nullable = true)
#  |-- dept_name: string (nullable = true)
#  |-- standardized_dept_name: string (nullable = true)
#  |-- dept_subject_to_SLA: string (nullable = true)

# %% [markdown]
# ### Extract the year from the case_closed_date column.

# %%
df_case.withColumn('year', substring('case_closed_date', 0, 4)).show()
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+
# |1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|
# |1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|
# |1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|
# |1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|
# |1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|
# |1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018|
# |1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|
# |1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|
# |1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|
# |1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+
# only showing top 20 rows

# %%
df_case = df_case.withColumn('year', substring('case_closed_date', 0, 4))

# %%
df_case.show()
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+
# |1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|
# |1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|
# |1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|
# |1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|
# |1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|
# |1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018|
# |1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|
# |1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|
# |1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|
# |1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|
# |1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# |1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+
# only showing top 20 rows

# %%
# df_case.withColumn('year', substring('case_closed_date', 0, 4).alias('year')).toPandas()

# %% [markdown]
# ### Convert num_days_late from days to hours in new columns num_hours_late.

# %%
df_case = df_case.withColumn('num_hours_late', df_case.num_days_late * 24)

# %%
df_case.show()
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|     num_hours_late|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+
# |1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|       NO| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|     -23964.2102784|
# |1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|       NO|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|-48.302500007999996|
# |1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|       NO|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|      -72.536111112|
# |1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|       NO|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|      -360.27555552|
# |1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|      YES|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|  8.931944448000001|
# |1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|       NO|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018| -713.8555555199999|
# |1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.96166664|
# |1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|
# |1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|
# |1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|
# |1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|
# |1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95277776|
# |1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.95000000000005|
# |1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|       NO|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|      -352.95277776|
# |1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.94972232000003|
# |1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|-352.94138879999997|
# |1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.94416656|
# |1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|
# |1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|
# |1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|       NO|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|       -352.9355556|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Convert the case_late column to a boolean column.

# %%
df_case.withColumn('case_late', df_case.case_late == "YES" ).show()
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|   dept_division|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|     num_hours_late|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+
# |1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|Field Operations|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|     -23964.2102784|
# |1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|     Storm Water|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|-48.302500007999996|
# |1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|    false|       -3.022337963|        YES|     Storm Water|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|      -72.536111112|
# |1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Code Enforcement|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|      -360.27555552|
# |1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Field Operations|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|  8.931944448000001|
# |1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|    false|       -29.74398148|        YES|         Signals|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018| -713.8555555199999|
# |1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Code Enforcement|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.96166664|
# |1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Code Enforcement|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|
# |1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Code Enforcement|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|
# |1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|
# |1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Code Enforcement|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|
# |1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Code Enforcement|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95277776|
# |1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|          -14.70625|        YES|Code Enforcement|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.95000000000005|
# |1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Code Enforcement|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|      -352.95277776|
# |1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Code Enforcement|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.94972232000003|
# |1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Code Enforcement|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|-352.94138879999997|
# |1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Code Enforcement|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.94416656|
# |1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Code Enforcement|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|
# |1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Code Enforcement|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|
# |1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Code Enforcement|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|       -352.9355556|
# +----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+----------------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+
# only showing top 20 rows

# %%
df_case = df_case.withColumn('case_late', df_case.case_late == "YES" )

# %% [markdown]
# ### Convert the SLA_days columns to a double column.

# %%
df_case = df_case.withColumn("SLA_days", df_case.SLA_days.cast("double"))
df_case.printSchema()
# Out:
# root
#  |-- case_id: integer (nullable = true)
#  |-- case_opened_date: timestamp (nullable = true)
#  |-- case_closed_date: timestamp (nullable = true)
#  |-- SLA_due_date: timestamp (nullable = true)
#  |-- case_late: boolean (nullable = true)
#  |-- num_days_late: double (nullable = true)
#  |-- case_closed: string (nullable = true)
#  |-- dept_division: string (nullable = true)
#  |-- service_request_type: string (nullable = true)
#  |-- SLA_days: double (nullable = true)
#  |-- case_status: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- request_address: string (nullable = true)
#  |-- council_district: integer (nullable = true)
#  |-- year: string (nullable = true)
#  |-- num_hours_late: double (nullable = true)

# %% [markdown]
# ### Pull it all together (again)

# %%
df_join2 = df_case.join(df_dept, "dept_division", "inner")
df_join2.show()
# Out:
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|     num_hours_late|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|     -23964.2102784|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|-48.302500007999996|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|    false|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|      -72.536111112|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|      -360.27555552|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|  8.931944448000001|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|    false|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018| -713.8555555199999|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.96166664|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95277776|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.95000000000005|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|      -352.95277776|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.94972232000003|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|-352.94138879999997|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.94416656|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|       -352.9355556|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Create a DataFrame with all combinations of council_district and service_request_type (regardless of whether the combination is observed in the data).

# %%
df_allcombos = df_case.join(df_dept, df_case.dept_division == df_dept.dept_division, "full_outer")
df_allcombos.show(3)
# Out:
# +----------+-------------------+-------------------+-------------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+--------------------+----------------+----+-------------------+-------------+--------------------+----------------------+-------------------+
# |   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|num_days_late|case_closed|dept_division|service_request_type|SLA_days|case_status|source_id|     request_address|council_district|year|     num_hours_late|dept_division|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------+-------------------+-------------------+-------------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+--------------------+----------------+----+-------------------+-------------+--------------------+----------------------+-------------------+
# |1014127378|2018-01-01 08:24:00|2018-01-02 07:37:00|2018-01-03 08:24:00|    false|  -1.03287037|        YES|Miscellaneous|   Dead Animal - Cat|     2.0|     Closed|   139344|7059  TIMBERCREEK...|               6|2018|       -24.78888888|Miscellaneous|Solid Waste Manag...|           Solid Waste|                YES|
# |1014127411|2018-01-01 10:14:00|2018-01-02 06:22:00|2018-01-03 10:14:00|    false| -1.160555556|        YES|Miscellaneous|   Dead Animal - Dog|     2.0|     Closed|   139344|6410  IH 35 N, Sa...|               2|2018|      -27.853333344|Miscellaneous|Solid Waste Manag...|           Solid Waste|                YES|
# |1014127439|2018-01-01 11:09:00|2018-01-02 07:27:00|2018-01-03 11:09:00|    false| -1.154386574|        YES|Miscellaneous|   Dead Animal - Cat|     2.0|     Closed|   139344|5013  EVERS RD, S...|               7|2018|-27.705277776000003|Miscellaneous|Solid Waste Manag...|           Solid Waste|                YES|
# +----------+-------------------+-------------------+-------------------+---------+-------------+-----------+-------------+--------------------+--------+-----------+---------+--------------------+----------------+----+-------------------+-------------+--------------------+----------------------+-------------------+
# only showing top 3 rows

# %% [markdown]
# ### Join the case data with the source and department data.

# %%
df_source = spark.read.csv('./sa311/source.csv', sep=",", header=True, inferSchema=True)

# %%
df_source.show(2)
# Out:
# +---------+----------------+
# |source_id| source_username|
# +---------+----------------+
# |   100137|Merlene Blodgett|
# |   103582|     Carmen Cura|
# +---------+----------------+
# only showing top 2 rows

# %%
df_join2.show()
# Out:
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+
# |   dept_division|   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|     num_hours_late|           dept_name|standardized_dept_name|dept_subject_to_SLA|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|     -23964.2102784|Animal Care Services|  Animal Care Services|                YES|
# |     Storm Water|1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|-48.302500007999996|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |     Storm Water|1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|    false|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|      -72.536111112|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|      -360.27555552|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Field Operations|1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|  8.931944448000001|Animal Care Services|  Animal Care Services|                YES|
# |         Signals|1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|    false|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018| -713.8555555199999|Trans & Cap Impro...|  Trans & Cap Impro...|                YES|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.96166664|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95277776|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.95000000000005|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|      -352.95277776|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.94972232000003|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|-352.94138879999997|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.94416656|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|       -352.9355556|Code Enforcement ...|  DSD/Code Enforcement|                YES|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+
# only showing top 20 rows

# %%
df_all_files = df_join2.join(df_source, df_join2.source_id == df_source.source_id, 'left_outer')
df_all_files.show()
# Out:
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+---------+---------------+
# |   dept_division|   case_id|   case_opened_date|   case_closed_date|       SLA_due_date|case_late|      num_days_late|case_closed|service_request_type|          SLA_days|case_status|source_id|     request_address|council_district|year|     num_hours_late|           dept_name|standardized_dept_name|dept_subject_to_SLA|source_id|source_username|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+---------+---------------+
# |Field Operations|1014127332|2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|    false| -998.5087616000001|        YES|        Stray Animal|             999.0|     Closed| svcCRMLS|2315  EL PASO ST,...|               5|2018|     -23964.2102784|Animal Care Services|  Animal Care Services|                YES| svcCRMLS|       svcCRMLS|
# |     Storm Water|1014127333|2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|    false|-2.0126041669999997|        YES|Removal Of Obstru...|       4.322222222|     Closed| svcCRMSS|2215  GOLIAD RD, ...|               3|2018|-48.302500007999996|Trans & Cap Impro...|  Trans & Cap Impro...|                YES| svcCRMSS|       svcCRMSS|
# |     Storm Water|1014127334|2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|    false|       -3.022337963|        YES|Removal Of Obstru...|       4.320729167|     Closed| svcCRMSS|102  PALFREY ST W...|               3|2018|      -72.536111112|Trans & Cap Impro...|  Trans & Cap Impro...|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127335|2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|    false|       -15.01148148|        YES|Front Or Side Yar...|       16.29188657|     Closed| svcCRMSS|114  LA GARDE ST,...|               3|2018|      -360.27555552|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Field Operations|1014127336|2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|     true|0.37216435200000003|        YES|Animal Cruelty(Cr...|             0.125|     Closed| svcCRMSS|734  CLEARVIEW DR...|               7|2018|  8.931944448000001|Animal Care Services|  Animal Care Services|                YES| svcCRMSS|       svcCRMSS|
# |         Signals|1014127337|2018-01-01 06:28:00|2018-01-01 14:38:00|2018-01-31 08:30:00|    false|       -29.74398148|        YES|Traffic Signal Op...|       30.08446759|     Closed| svcCRMSS|BANDERA RD and BR...|               7|2018| -713.8555555199999|Trans & Cap Impro...|  Trans & Cap Impro...|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127338|2018-01-01 06:57:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70673611|        YES|Front Or Side Yar...|       16.06429398|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.96166664|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127339|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Front Or Side Yar...|16.063796300000003|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127340|2018-01-01 06:58:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70662037|        YES|Right Of Way/Side...|       16.06333333|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95888888|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127341|2018-01-01 06:59:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|        16.0628588|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127342|2018-01-01 07:00:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70649306|        YES|Front Or Side Yar...|       16.06237269|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95583344|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127343|2018-01-01 07:02:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Right Of Way/Side...|       16.06104167|     Closed| svcCRMSS|10133  FIGARO CAN...|               4|2018|      -352.95277776|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127344|2018-01-01 07:02:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|          -14.70625|        YES|Front Or Side Yar...|       16.06059028|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.95000000000005|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127345|2018-01-01 07:03:00|2018-01-02 15:32:00|2018-01-17 08:30:00|    false|       -14.70636574|        YES|Front Or Side Yar...|       16.06011574|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|      -352.95277776|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127346|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70623843|        YES|Right Of Way/Side...|       16.05953704|     Closed| svcCRMSS|10129  BOXING PAS...|               4|2018|-352.94972232000003|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127347|2018-01-01 07:04:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|-14.705891199999998|        YES|Front Or Side Yar...|       16.05907407|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|-352.94138879999997|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127348|2018-01-01 07:05:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70600694|        YES|Front Or Side Yar...|       16.05864583|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.94416656|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127349|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Right Of Way/Side...|       16.05819444|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127350|2018-01-01 07:06:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70576389|        YES|Front Or Side Yar...|       16.05775463|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|      -352.93833336|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# |Code Enforcement|1014127351|2018-01-01 07:07:00|2018-01-02 15:33:00|2018-01-17 08:30:00|    false|       -14.70564815|        YES|Front Or Side Yar...|       16.05733796|     Closed| svcCRMSS|834  BARREL POINT...|               4|2018|       -352.9355556|Code Enforcement ...|  DSD/Code Enforcement|                YES| svcCRMSS|       svcCRMSS|
# +----------------+----------+-------------------+-------------------+-------------------+---------+-------------------+-----------+--------------------+------------------+-----------+---------+--------------------+----------------+----+-------------------+--------------------+----------------------+-------------------+---------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### Are there any cases that do not have a request source?

# %%
df_join2.join(df_source, df_join2.source_id == df_source.source_id, "left_anti").show()
# Out:
# +-------------+-------+----------------+----------------+------------+---------+-------------+-----------+--------------------+--------+-----------+---------+---------------+----------------+----+--------------+---------+----------------------+-------------------+
# |dept_division|case_id|case_opened_date|case_closed_date|SLA_due_date|case_late|num_days_late|case_closed|service_request_type|SLA_days|case_status|source_id|request_address|council_district|year|num_hours_late|dept_name|standardized_dept_name|dept_subject_to_SLA|
# +-------------+-------+----------------+----------------+------------+---------+-------------+-----------+--------------------+--------+-----------+---------+---------------+----------------+----+--------------+---------+----------------------+-------------------+
# +-------------+-------+----------------+----------------+------------+---------+-------------+-----------+--------------------+--------+-----------+---------+---------------+----------------+----+--------------+---------+----------------------+-------------------+

# %% [markdown]
# ## No

# %% [markdown]
# ### Who are the top 10 service request types in terms of number of requests?

# %%
df_all_files.toPandas().head()
# Out:
#       dept_division     case_id    case_opened_date    case_closed_date  \
# 0  Field Operations  1014127332 2018-01-01 00:42:00 2018-01-01 12:29:00
# 1       Storm Water  1014127333 2018-01-01 00:46:00 2018-01-03 08:11:00
# 2       Storm Water  1014127334 2018-01-01 00:48:00 2018-01-02 07:57:00
# 3  Code Enforcement  1014127335 2018-01-01 01:29:00 2018-01-02 08:13:00
# 4  Field Operations  1014127336 2018-01-01 01:34:00 2018-01-01 13:29:00
#
#          SLA_due_date  case_late  num_days_late case_closed  \
# 0 2020-09-26 00:42:00      False    -998.508762         YES
# 1 2018-01-05 08:30:00      False      -2.012604         YES
# 2 2018-01-05 08:30:00      False      -3.022338         YES
# 3 2018-01-17 08:30:00      False     -15.011481         YES
# 4 2018-01-01 04:34:00       True       0.372164         YES
#
#          service_request_type    SLA_days       ...       source_id  \
# 0                Stray Animal  999.000000       ...        svcCRMLS
# 1      Removal Of Obstruction    4.322222       ...        svcCRMSS
# 2      Removal Of Obstruction    4.320729       ...        svcCRMSS
# 3  Front Or Side Yard Parking   16.291887       ...        svcCRMSS
# 4    Animal Cruelty(Critical)    0.125000       ...        svcCRMSS
#
#                          request_address council_district  year  \
# 0   2315  EL PASO ST, San Antonio, 78207                5  2018
# 1    2215  GOLIAD RD, San Antonio, 78223                3  2018
# 2  102  PALFREY ST W, San Antonio, 78223                3  2018
# 3   114  LA GARDE ST, San Antonio, 78223                3  2018
# 4  734  CLEARVIEW DR, San Antonio, 78228                7  2018
#
#   num_hours_late                  dept_name    standardized_dept_name  \
# 0  -23964.210278       Animal Care Services      Animal Care Services
# 1     -48.302500   Trans & Cap Improvements  Trans & Cap Improvements
# 2     -72.536111   Trans & Cap Improvements  Trans & Cap Improvements
# 3    -360.275556  Code Enforcement Services      DSD/Code Enforcement
# 4       8.931944       Animal Care Services      Animal Care Services
#
#   dept_subject_to_SLA source_id source_username
# 0                 YES  svcCRMLS        svcCRMLS
# 1                 YES  svcCRMSS        svcCRMSS
# 2                 YES  svcCRMSS        svcCRMSS
# 3                 YES  svcCRMSS        svcCRMSS
# 4                 YES  svcCRMSS        svcCRMSS
#
# [5 rows x 21 columns]

# %%
df_all_files.dtypes
# Out:
# [('dept_division', 'string'),
#  ('case_id', 'int'),
#  ('case_opened_date', 'timestamp'),
#  ('case_closed_date', 'timestamp'),
#  ('SLA_due_date', 'timestamp'),
#  ('case_late', 'boolean'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'string'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'int'),
#  ('year', 'string'),
#  ('num_hours_late', 'double'),
#  ('dept_name', 'string'),
#  ('standardized_dept_name', 'string'),
#  ('dept_subject_to_SLA', 'string'),
#  ('source_id', 'string'),
#  ('source_username', 'string')]

# %%
top_service_requests = df_all_files.groupBy('service_request_type').agg(count('service_request_type').alias('count')).sort('count',ascending=False)
top_service_requests.show(10)
# Out:
# +--------------------+-----+
# |service_request_type|count|
# +--------------------+-----+
# |           No Pickup|89210|
# |Overgrown Yard/Trash|66403|
# |        Bandit Signs|32968|
# |        Damaged Cart|31163|
# |Front Or Side Yar...|28920|
# |        Stray Animal|27361|
# |Aggressive Animal...|25492|
# |Cart Exchange Req...|22608|
# |Junk Vehicle On P...|21649|
# |     Pot Hole Repair|20827|
# +--------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ### Who are the top 10 service request types in terms of average days late?

# %%
top_service_late = df_all_files.groupBy('service_request_type').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_service_late.show(10)
# Out:
# +--------------------+------------------+
# |service_request_type|     avg_days_late|
# +--------------------+------------------+
# |  Zoning: Junk Yards| 175.9563621042095|
# |Labeling for Used...|162.43032902285717|
# |Record Keeping of...|153.99724039428568|
# |Signage Requied f...|151.63868055333333|
# |Storage of Used M...|     142.112556415|
# |Zoning: Recycle Yard|135.92851612479797|
# |Donation Containe...|131.75610506358706|
# |License Requied U...|128.79828704142858|
# |Traffic Signal Gr...|101.79846062200002|
# |           Complaint| 72.87050230311695|
# +--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ### Does number of days late depend on department?

# %%
top_service_late_bydept = df_all_files.groupBy('service_request_type', 'dept_division').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_service_late_bydept.show(10)
# Out:
# +--------------------+--------------------+------------------+
# |service_request_type|       dept_division|     avg_days_late|
# +--------------------+--------------------+------------------+
# |  Zoning: Junk Yards|    Code Enforcement| 175.9563621042095|
# |Labeling for Used...|Code Enforcement ...|162.43032902285717|
# |Record Keeping of...|Code Enforcement ...|153.99724039428568|
# |Signage Requied f...|Code Enforcement ...|151.63868055333333|
# |Storage of Used M...|Code Enforcement ...|     142.112556415|
# |Zoning: Recycle Yard|Code Enforcement ...|135.92851612479797|
# |Donation Containe...|    Code Enforcement|131.75610506358706|
# |License Requied U...|Code Enforcement ...|128.79828704142858|
# |Traffic Signal Gr...|             Signals|101.79846062200002|
# |Used Mattress Ins...|Code Enforcement ...| 92.93570056835293|
# +--------------------+--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ### It seems like Code Enforcement Department has a lot of very late request types...

# %%
top_dept_late = df_all_files.groupBy('dept_division').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_dept_late.show(10)
# Out:
# +--------------------+------------------+
# |       dept_division|     avg_days_late|
# +--------------------+------------------+
# |Code Enforcement ...|135.92851612479797|
# |        Reservations|       66.03116319|
# |     311 Call Center|59.737091496300785|
# |Director's Office...|37.570646702950086|
# |Engineering Division| 13.43372455586971|
# |               Shops|  9.64126176872269|
# |           Tree Crew| 4.723282812065399|
# |         Solid Waste|3.5190239198762248|
# |              Trades| 3.231977141276932|
# |Clean and Green N...| 1.691468919487805|
# +--------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ## How do number of days late depend on department division and request type?

# %%
top_dept_late_byservice = df_all_files.groupBy('dept_division', 'service_request_type').agg(mean('num_days_late').alias('avg_days_late')).sort('avg_days_late',ascending=False)
top_dept_late_byservice.show(20)
# Out:
# +--------------------+--------------------+------------------+
# |       dept_division|service_request_type|     avg_days_late|
# +--------------------+--------------------+------------------+
# |    Code Enforcement|  Zoning: Junk Yards| 175.9563621042095|
# |Code Enforcement ...|Labeling for Used...|162.43032902285717|
# |Code Enforcement ...|Record Keeping of...|153.99724039428568|
# |Code Enforcement ...|Signage Requied f...|151.63868055333333|
# |Code Enforcement ...|Storage of Used M...|     142.112556415|
# |Code Enforcement ...|Zoning: Recycle Yard|135.92851612479797|
# |    Code Enforcement|Donation Containe...|131.75610506358706|
# |Code Enforcement ...|License Requied U...|128.79828704142858|
# |             Signals|Traffic Signal Gr...|101.79846062200002|
# |Code Enforcement ...|Used Mattress Ins...| 92.93570056835293|
# |Code Enforcement ...|        Bandit Signs| 87.61764120320001|
# |     311 Call Center|           Complaint| 72.87050230311695|
# |    Code Enforcement|             Vendors|   66.548098985078|
# |        Reservations|Reservation Assis...|       66.03116319|
# |    Waste Collection|Contracted Servic...|     62.2454525543|
# |    Code Enforcement|   No Address Posted|59.875640733625936|
# |    Code Enforcement|         Curbstoning|59.808628977605274|
# |Director's Office...|Status: On-Going ...|37.570646702950086|
# |Code Enforcement ...|Historical Buildi...|31.567148565454545|
# |    Waste Collection| Service Information|29.177355749054875|
# +--------------------+--------------------+------------------+
# only showing top 20 rows

# %%
top_dept_late_byservice.select('service_request_type').show(truncate=False)
# Out:
# +--------------------------------------+
# |service_request_type                  |
# +--------------------------------------+
# |Zoning: Junk Yards                    |
# |Labeling for Used Mattress            |
# |Record Keeping of Used Mattresses     |
# |Signage Requied for Sale of Used Mattr|
# |Storage of Used Mattress              |
# |Zoning: Recycle Yard                  |
# |Donation Container Enforcement        |
# |License Requied Used Mattress Sales   |
# |Traffic Signal Graffiti               |
# |Used Mattress Inspection              |
# |Bandit Signs                          |
# |Complaint                             |
# |Vendors                               |
# |Reservation Assistance                |
# |Contracted Service Issues             |
# |No Address Posted                     |
# |Curbstoning                           |
# |Status: On-Going CIMS Projects        |
# |Historical Building (No Permits)      |
# |Service Information                   |
# +--------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ### The department division might be related to the number of days late. Further investigation is needed...
# ### It might be that the department with the most late SLA's is the department that is flooded with the most requests...

# %%
dept_number_requests = df_all_files.groupBy('dept_division').agg(count('service_request_type').alias('count_requests')).sort('count_requests',ascending=False)
dept_number_requests.show(10)
# Out:
# +------------------+--------------+
# |     dept_division|count_requests|
# +------------------+--------------+
# |  Code Enforcement|        274298|
# |  Waste Collection|        220696|
# |  Field Operations|        119362|
# |     Miscellaneous|         46165|
# |           Streets|         39193|
# |           Signals|         21095|
# |             Brush|         18610|
# |Signs and Markings|         18127|
# | Dangerous Premise|         15648|
# | Graffiti (IntExp)|         15154|
# +------------------+--------------+
# only showing top 10 rows

# %% [markdown]
# ### ...we see that Code Enforcement, which has the most late SLA's, does have the most count requests.
# ### But Waste Collection which has the second most count requests does not show up as having late SLA's so this department is running efficiently.
# ### Of the 20 highest average number of days late, most of them are related to waste and other kinds of defacement or destruction of property.
